# %% [markdown]
# # 더미데이터 생성

# %%
import csv
import random
from datetime import datetime, timedelta

def generate_transaction_data(num_rows=1000, seed=42):
    random.seed(seed)

    merchants = [
        '롯데월드', '세븐일레븐', '이마트', '맥도날드', '세인트존스호텔',
        'GS25', '톡스앤필의원', '롯데리아', '카카오프렌즈', '롯데시네마',
        'CGV', '코스트코', '(주)에이비카페', '런던베이글', '강동도서관',
        '오렌지주유소', '더벤티', '쿰베오', '메가커피', '은혜공인중개사무소', '정약국'
    ]

    amount_ranges = {
        '롯데월드': (50000, 150000),
        '세븐일레븐': (1000, 15000),
        '이마트': (5000, 45000),
        '맥도날드': (3000, 20000),
        '세인트존스호텔': (80000, 150000),
        'GS25': (1000, 12000),
        '톡스앤필의원': (30000, 200000),
        '롯데리아': (2000, 15000),
        '카카오프렌즈': (5000, 25000),
        '롯데시네마': (8000, 25000),
        'CGV': (8000, 25000),
        '코스트코': (20000, 80000),
        '(주)에이비카페': (4000, 15000),
        '런던베이글': (3000, 25000),
        '강동도서관': (1000, 5000),
        '오렌지주유소': (40000, 120000),
        '더벤티': (3000, 12000),
        '쿰베오': (8000, 20000),
        '메가커피': (2000, 12000),
        '은혜공인중개사무소': (500000, 2000000),
        '정약국': (5000, 30000),
    }


    profile_weights = {
        1: {'세븐일레븐': 35, 'GS25': 30, '이마트': 20, '코스트코': 10, '정약국': 5, '롯데월드': 1, 'CGV': 2, '롯데시네마': 2},
        2: {'(주)에이비카페': 30, '메가커피': 25, '더벤티': 20, '런던베이글': 15, '쿰베오': 10, '맥도날드': 15, '롯데리아': 10, '세븐일레븐': 5},
        3: {'CGV': 35, '롯데시네마': 30, '롯데월드': 8, '(주)에이비카페': 10, '메가커피': 6, '세븐일레븐': 6, '이마트': 5},
        4: {'톡스앤필의원': 45, '정약국': 25, '세븐일레븐': 10, '이마트': 10, '(주)에이비카페': 5, 'CGV': 2, '롯데시네마': 2, '롯데월드': 1},
        5: {'오렌지주유소': 40, '코스트코': 25, '이마트': 20, '세븐일레븐': 10, '(주)에이비카페': 5},
        6: {m: 1 for m in merchants},
        7: {'(주)에이비카페': 25, '메가커피': 20, '더벤티': 15, '런던베이글': 12, '쿰베오': 10, '세븐일레븐': 10, '이마트': 8},
        8: {'세븐일레븐': 20, 'GS25': 15, '이마트': 15, '코스트코': 10, 'CGV': 15, '롯데시네마': 15, '(주)에이비카페': 10},
        9: {'CGV': 25, '롯데시네마': 25, '(주)에이비카페': 15, '런던베이글': 10, '맥도날드': 10, '세인트존스호텔': 5, '롯데월드': 10},
        10: {'은혜공인중개사무소': 3, '이마트': 25, '코스트코': 20, '세븐일레븐': 20, '정약국': 10, '오렌지주유소': 10, '(주)에이비카페': 12},
    }

    # 빠진 상점은 낮은 기본 가중치로 채워 넣기
    def get_weights_for_member(mid: int):
        base = {m: 0.5 for m in merchants}  # 기본 0.5
        prof = profile_weights.get(mid, {})
        base.update(prof)
        # random.choices는 리스트 순서대로 weights를 요구
        return [base[m] for m in merchants]

    start_date = datetime(2025, 6, 1)
    end_date = datetime(2025, 8, 31)
    date_range = (end_date - start_date).days

    with open('dataset/member.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['memberId', 'amount', 'merchant', 'date'])

        for i in range(num_rows):
            member_id = (i % 10) + 1

            # 멤버별 가중치로 상점 선택
            weights = get_weights_for_member(member_id)
            merchant = random.choices(merchants, weights=weights, k=1)[0]

            min_amount, max_amount = amount_ranges[merchant]
            amount = random.randint(min_amount, max_amount)
            amount = int(amount * random.uniform(0.8, 1.2))  # 약간의 변동

            random_days = random.randint(0, date_range)
            transaction_date = start_date + timedelta(days=random_days)
            date_str = transaction_date.strftime('%Y-%m-%d')

            writer.writerow([member_id, amount, merchant, date_str])

    print(f"member.csv 파일 생성 완료 ({num_rows}행)")

if __name__ == '__main__':
    generate_transaction_data(1000)
# Out:
# member.csv 파일 생성 완료 (1000행)

# %% [markdown]
# # 데이터 구성 확인

# %%
import pandas as pd

# CSV 파일 경로 지정
file_path = 'dataset/member.csv'

# CSV 불러오기
df = pd.read_csv(file_path)

# 상위 5개 행 출력
df.head()
# Out:
#    memberId  amount merchant        date
# 0         1    1545     GS25  2025-07-02
# 1         2   11829     롯데리아  2025-08-09
# 2         3    6430    세븐일레븐  2025-06-12
# 3         4  169105   톡스앤필의원  2025-08-11
# 4         5   39402      이마트  2025-07-28

# %% [markdown]
# # 사용처 기반 카테고리 추출

# %%
import os
import time
import requests
import pandas as pd
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.getenv("KAKAO_API_KEY")
HEADERS = {"Authorization": f"KakaoAK {API_KEY}"}
SEARCH_URL = "https://dapi.kakao.com/v2/local/search/keyword.json"

# 대분류로 그대로 인정할 목록
TOP_CATEGORIES = {
    "음식점",
    "서비스,산업",
    "가정,생활",
    "생활, 가전",  # 응답 변동 대비 별칭 처리
    "의료,건강",
    "교육,학문",
    "교통,수송",
    "스포츠,레저",
    "부동산",
    "문화,예술",
    "여행",
}

# '가정,생활'로 합치는 별칭(응답 일관성 대비)
HOME_LIFE_ALIASES = {"가정,생활", "생활, 가전"}

def parse_category_name(category_name: str) -> str:
    """
    카카오 category_name을 규칙에 맞춰 최종 카테고리로 매핑
    """
    if not category_name:
        return "기타"

    # "A > B > C" 형태를 토큰화
    tokens = [t.strip() for t in category_name.split(">") if t.strip()]
    if not tokens:
        return "기타"

    top = tokens[0]  # 대분류
    subs = tokens[1:]  # 중분류 이하

    # ---- 음식점 규칙 ----
    if top == "음식점":
        # 중분류 어디든 '카페'가 있으면 카페로
        if any("카페" in s for s in subs):
            return "카페"
        return "음식점"

    # ---- 가정,생활 규칙 (별칭 포함) ----
    if top in HOME_LIFE_ALIASES:
        # 우선순위: 편의점/대형마트/패션/문구,사무용품
        # 문구,사무용품을 다양한 표기로 허용
        if any("편의점" in s for s in subs):
            return "편의점"
        if any("대형마트" in s for s in subs):
            return "대형마트"
        if any("패션" in s for s in subs):
            return "패션"
        if any(("문구" in s and "사무" in s) or ("문구,사무용품" in s) for s in subs):
            return "문구,사무용품"
        # 없으면 대분류로
        return "가정,생활"

    # ---- 여행 규칙 ----
    if top == "여행":
        if any("숙박" in s for s in subs):
            return "숙박"
        # 관광,명소/관광명소/명소 등 허용
        if any(("관광" in s and "명소" in s) or ("관광명소" in s) or (s.strip() == "명소") for s in subs):
            return "관광,명소"
        return "여행"

    # ---- 그 외 대분류는 그대로 반환 ----
    if top in TOP_CATEGORIES:
        # '생활, 가전'은 표준화해서 '가정,생활'로 통일해 주면 좋음
        return "가정,생활" if top in HOME_LIFE_ALIASES else top

    # 어떤 규칙에도 해당 안 되면 기타
    return "기타"


def get_category_from_kakao(merchant_name: str, sleep_sec: float = 0.0) -> str:
    """
    상호명으로 카카오 키워드검색 호출 -> category_name 파싱 -> 규칙 매핑
    """
    if not merchant_name or not merchant_name.strip():
        return "기타"

    try:
        resp = requests.get(
            SEARCH_URL,
            headers=HEADERS,
            params={"query": merchant_name, "size": 1},  # 가장 관련 높은 1건
            timeout=5,
        )
        # 간단한 rate control (필요시)
        if sleep_sec > 0:
            time.sleep(sleep_sec)

        if resp.status_code != 200:
            return "기타"

        docs = resp.json().get("documents", [])
        if not docs:
            return "기타"

        cat_name = docs[0].get("category_name", "")
        return parse_category_name(cat_name)

    except requests.RequestException:
        return "기타"

df = pd.read_csv("dataset/member.csv")

# 새 컬럼: rules_category (규칙 기반 최종 카테고리)
df["category"] = df["merchant"].apply(lambda x: get_category_from_kakao(str(x)))
df.to_csv("dataset/member_with_category.csv", index=False, encoding="utf-8-sig")
df.head()
# Out:
#    memberId  amount merchant        date category
# 0         1    1545     GS25  2025-07-02      편의점
# 1         2   11829     롯데리아  2025-08-09      음식점
# 2         3    6430    세븐일레븐  2025-06-12      편의점
# 3         4  169105   톡스앤필의원  2025-08-11    의료,건강
# 4         5   39402      이마트  2025-07-28     대형마트

# %% [markdown]
# ## 카테고리별 MCC 수동 매핑

# %%
import pandas as pd

# 카카오 기준에 맞춰 MCC 수동 매핑
mcc_mapping = {

    "음식점": "5812",
    "카페": "5814",
    "편의점": "5499",
    "대형마트": "5300",
    "패션": "5651",
    "문구,사무용품": "5943",
    "서비스,산업": "7399",
    "생활, 가전": "5722",
    "의료,건강": "8062",
    "교육,학문": "8299",
    "교통,수송": "4111",
    "스포츠,레저": "7997",
    "부동산": "6513",
    "문화,예술": "7991",
    "관광,명소": "7991",
    "여행": "4722",
    "숙박": "7011",
    "기타": "0000"
}


# CSV 파일 불러오기
df = pd.read_csv('dataset/member_with_category.csv')

# category 컬럼(대분류명)을 기반으로 MCC 코드를 매핑해 새 컬럼 생성
df['mcc'] = df['category'].map(mcc_mapping).fillna('0000')  # 미매핑시 '0000' 처리

# 결과 저장
df.to_csv('dataset/member_with_category_mcc.csv', index=False)

df.head()
# Out:
#    memberId  amount merchant        date category   mcc
# 0         1    1545     GS25  2025-07-02      편의점  5499
# 1         2   11829     롯데리아  2025-08-09      음식점  5812
# 2         3    6430    세븐일레븐  2025-06-12      편의점  5499
# 3         4  169105   톡스앤필의원  2025-08-11    의료,건강  8062
# 4         5   39402      이마트  2025-07-28     대형마트  5300

# %% [markdown]
# ## MCC 기반 탄소 배출량 매핑

# %%
import pandas as pd
import requests
import uuid

# 1) member_with_category_mcc 파일을 같은 폴더에 두고 불러오기
df = pd.read_csv('dataset/member_with_category_mcc.csv')
from dotenv import load_dotenv
load_dotenv()
import os

# 2) demo API URL
API_URL = os.getenv("CARBON_API_URL")

# 3) 각 행마다 demo 호출 및 carbonEmissionInOunces 수집
carbon_list = []
for _, row in df.iterrows():
    tx_id = str(uuid.uuid4())
    payload = [
        {
            "transactionId": tx_id,
            "amount": {
                "value": str(row['amount']),
                "currencyCode": "KRW"
            },
            "transactionDate": row['date'],
            "mcc": int(row['mcc']),
            "merchantCountryCode": "KOR",
            "paymentNetwork": "MASTERCARD",
            "cardBrand": "OTH"
        }
    ]
    resp = requests.post(API_URL, json=payload)
    if resp.status_code == 200:
        data = resp.json()[0]
        carbon_value = data.get('carbonEmissionInOunces')
        # None이나 Null인 경우 0으로 대체
        if carbon_value is None:
            carbon_value = 0
        carbon_list.append(carbon_value)
    else:
        carbon_list.append(0)  # 에러 시에도 0으로 처리

# 4) 원본 DataFrame에 컬럼 추가 (컬럼명 'carbon'으로 변경)
df['carbon'] = carbon_list

# 5) final_member.csv 로 저장
df.to_csv('dataset/final_member.csv', index=False)

df.head()
# Out:
#    memberId  amount merchant        date category   mcc  carbon
# 0         1    1545     GS25  2025-07-02      편의점  5499    8.88
# 1         2   11829     롯데리아  2025-08-09      음식점  5812  129.70
# 2         3    6430    세븐일레븐  2025-06-12      편의점  5499   36.97
# 3         4  169105   톡스앤필의원  2025-08-11    의료,건강  8062  690.19
# 4         5   39402      이마트  2025-07-28     대형마트  5300  222.16

# %% [markdown]
# ## 데이터 기반 탄소 배출 분석

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

columns = ['memberId', 'amount', 'merchant', 'date', 'category', 'mcc', 'carbon']
df = pd.read_csv('dataset/final_member.csv', names=columns, header=None)

df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d', errors='coerce')
df['amount'] = pd.to_numeric(df['amount'], errors='coerce').fillna(0)
df['carbon'] = pd.to_numeric(df['carbon'], errors='coerce').fillna(0)

# ===== 1) 기간별 멤버 탄소/금액 합산/등수/평균대비/상위% =====
def get_rank_by_period(df, start_date, end_date):
    mask = (df['date'] >= pd.to_datetime(start_date)) & (df['date'] <= pd.to_datetime(end_date))
    df_period = df.loc[mask]

    carbon_sum = df_period.groupby('memberId')['carbon'].sum().sort_index()
    amount_sum = df_period.groupby('memberId')['amount'].sum().sort_index()

    if carbon_sum.empty:
        return pd.DataFrame(columns=['memberId','carbon_sum','amount_sum','rank','vs_avg','top_label'])

    avg_carbon = carbon_sum.mean()
    ranks = carbon_sum.rank(method='dense', ascending=True).astype(int)

    if avg_carbon == 0:
        diff_label = pd.Series(["0%"] * len(carbon_sum), index=carbon_sum.index)
    else:
        diff_percent = ((carbon_sum - avg_carbon) / avg_carbon * 100).round(1)
        diff_label = diff_percent.apply(lambda x: f"▲ {abs(x)}%" if x > 0 else (f"▼ {abs(x)}%" if x < 0 else "0%"))

    n_members = len(carbon_sum)
    top_percent = (ranks / n_members * 100).round(1)
    top_label = top_percent.apply(lambda x: f"상위 {x}%")

    result = pd.DataFrame({
        'memberId': carbon_sum.index,
        'carbon_sum': carbon_sum.values,
        'amount_sum': amount_sum.reindex(carbon_sum.index, fill_value=0).values,
        'rank': ranks.values,
        'vs_avg': diff_label.values,
        'top_label': top_label.values
    }).sort_values('rank').reset_index(drop=True)

    return result

# ===== 2) 멤버별 고/저탄소 업종 Top3 =====
def get_top3_categories_by_period(df, start_date, end_date):
    mask = (df['date'] >= pd.to_datetime(start_date)) & (df['date'] <= pd.to_datetime(end_date))
    df_period = df.loc[mask].copy()

    df_period = df_period[df_period['category'] != '기타']
    df_period['carbon'] = pd.to_numeric(df_period['carbon'], errors='coerce').fillna(0)

    grouped = df_period.groupby(['memberId', 'category'])['carbon'].sum().reset_index()

    top3_high = grouped.groupby('memberId', group_keys=False).apply(
        lambda x: x.nlargest(3, 'carbon')
    ).reset_index(drop=True)

    top3_low  = grouped.groupby('memberId', group_keys=False).apply(
        lambda x: x.nsmallest(3, 'carbon')
    ).reset_index(drop=True)

    return top3_high, top3_low

# ===== 3) 리포트 한 번에 뽑아주는 헬퍼 =====
def build_reports(df, start_date, end_date):
    today = pd.to_datetime('today').normalize()

    period_rank = get_rank_by_period(df, start_date, end_date)
    top3_high, top3_low = get_top3_categories_by_period(df, start_date, end_date)

    rank_day = get_rank_by_period(df, today, today)
    week_start = today - pd.Timedelta(days=6)
    rank_week = get_rank_by_period(df, week_start, today)
    month_start = today - pd.Timedelta(days=29)
    rank_month = get_rank_by_period(df, month_start, today)

    return {
        "period_rank": period_rank,
        "top3_high": top3_high,
        "top3_low": top3_low,
        "rank_day": rank_day,
        "rank_week": rank_week,
        "rank_month": rank_month,
    }

# ===== 4) 사용 예시 (Jupyter에서는 display로 보기) =====
reports = build_reports(df, '2025-06-05', '2025-07-31')
#
from IPython.display import display
print("저탄소 소비 랭킹")
display(reports['period_rank'].head(10))  #저탄소 소비 래킹
print("회원별 저탄소 소비 업종 TOP 3")
display(reports['top3_high'].head(10)) #저탄소 업종 Top3
print("회원별 고탄소 소비 업종 TOP 3")
display(reports['top3_low'].head(10)) #고탄소 업종 Top3
print("금일 탄소 소비 분석")
display(reports['rank_day'].head(10)) #금일 탄소 소비 분석
print("금주 탄소 소비 분석")
display(reports['rank_week'].head(10)) #금주 탄소 소비 분석
print("금월 탄소 소비 분석")
display(reports['rank_month'].head(10)) #금월 탄소 소비 분석
# Out:
# 저탄소 소비 랭킹
#   memberId  carbon_sum  amount_sum  rank    vs_avg  top_label
# 0        8     5187.35   2154511.0     1   ▼ 61.8%   상위 10.0%
# 1        3     5355.93   1353032.0     2   ▼ 60.6%   상위 20.0%
# 2        1     6110.26   1080564.0     3   ▼ 55.1%   상위 30.0%
# 3        2     6248.69    579541.0     4   ▼ 54.0%   상위 40.0%
# 4        7     7615.28    833120.0     5   ▼ 44.0%   상위 50.0%
# 5        6     7690.68   3833363.0     6   ▼ 43.4%   상위 60.0%
# 6        9    13323.48   1810147.0     7    ▼ 2.0%   상위 70.0%
# 7        4    15598.87   3699269.0     8   ▲ 14.7%   상위 80.0%
# 8       10    21430.82   1597523.0     9   ▲ 57.6%   상위 90.0%
# 9        5    47393.71   3391447.0    10  ▲ 248.6%  상위 100.0%
# 회원별 저탄소 소비 업종 TOP 3
#   memberId category    carbon
# 0        1     대형마트   4018.78
# 1        1      편의점   1566.41
# 2        1       카페    280.04
# 3       10    교통,수송  16486.80
# 4       10     대형마트   2894.28
# 5       10      편의점    786.61
# 6        2       카페   3839.55
# 7        2      음식점   2292.38
# 8        2      편의점    116.76
# 9        3    문화,예술   2434.48
# 회원별 고탄소 소비 업종 TOP 3
#   memberId category   carbon
# 0        1    문화,예술   105.30
# 1        1    의료,건강   139.73
# 2        1       카페   280.04
# 3       10    문화,예술    41.63
# 4       10  문구,사무용품   100.94
# 5       10      음식점   180.95
# 6        2      편의점   116.76
# 7        2      음식점  2292.38
# 8        2       카페  3839.55
# 9        3  문구,사무용품   109.77
# 금일 탄소 소비 분석
#   memberId  carbon_sum  amount_sum  rank   vs_avg  top_label
# 0        1       66.99     11651.0     1  ▼ 62.8%   상위 16.7%
# 1        3      110.84     37479.0     2  ▼ 38.4%   상위 33.3%
# 2        6      130.59     11910.0     3  ▼ 27.5%   상위 50.0%
# 3        9      236.53     55503.0     4  ▲ 31.4%   상위 66.7%
# 4        8      250.05     55672.0     5  ▲ 38.9%   상위 83.3%
# 5        5      285.03     50552.0     6  ▲ 58.3%  상위 100.0%
# 금주 탄소 소비 분석
#   memberId  carbon_sum  amount_sum  rank    vs_avg  top_label
# 0       10      211.34   1411394.0     1   ▼ 78.5%   상위 10.0%
# 1        8      435.48    105172.0     2   ▼ 55.6%   상위 20.0%
# 2        1      447.70     78744.0     3   ▼ 54.4%   상위 30.0%
# 3        7      452.72     59563.0     4   ▼ 53.9%   상위 40.0%
# 4        3      594.56    177648.0     5   ▼ 39.4%   상위 50.0%
# 5        2      748.15     68232.0     6   ▼ 23.8%   상위 60.0%
# 6        6      959.53    145298.0     7    ▼ 2.2%   상위 70.0%
# 7        4     1560.05    361332.0     8   ▲ 59.0%   상위 80.0%
# 8        9     1995.66    272858.0     9  ▲ 103.4%   상위 90.0%
# 9        5     2408.61    152087.0    10  ▲ 145.4%  상위 100.0%
# 금월 탄소 소비 분석
#   memberId  carbon_sum  amount_sum  rank    vs_avg  top_label
# 0        8     2933.67    573314.0     1   ▼ 64.9%   상위 10.0%
# 1        3     3053.43    699614.0     2   ▼ 63.5%   상위 20.0%
# 2        2     3135.41    290618.0     3   ▼ 62.5%   상위 30.0%
# 3        6     3293.29   1279937.0     4   ▼ 60.6%   상위 40.0%
# 4        1     3579.03    618011.0     5   ▼ 57.2%   상위 50.0%
# 5        7     5697.34    688652.0     6   ▼ 31.8%   상위 60.0%
# 6        4     6640.08   1549331.0     7   ▼ 20.6%   상위 70.0%
# 7        9     6808.36    885697.0     8   ▼ 18.5%   상위 80.0%
# 8       10    16675.47   2510242.0     9   ▲ 99.5%   상위 90.0%
# 9        5    31769.87   1930777.0    10  ▲ 280.1%  상위 100.0%

# %%
import math
import pandas as pd

def parse_dates_mixed(series):

    try:
        # pandas 2.0+ 에서 지원
        return pd.to_datetime(series, format="mixed", errors="coerce")
    except Exception:
        s1 = pd.to_datetime(series, format="%Y%m%d", errors="coerce")
        s2 = pd.to_datetime(series, format="%Y-%m-%d", errors="coerce")
        return s1.fillna(s2)


def sdiv(a, b):
    return a / b if (pd.notna(a) and pd.notna(b) and b != 0) else 0

df = pd.read_csv("dataset/final_member.csv")

if 'date' in df.columns:
    df['date'] = parse_dates_mixed(df['date'])

# 여가 관련 카테고리(시간 로직 제거, 카테고리 기반만 사용)
LEISURE_CATS = ['카페', '음식점', '스포츠,레저', '여행', '문화,예술','관광,명소']

summary_list = []

for member_id in df['memberId'].unique():
    sub = df[df['memberId'] == member_id].copy()  # copy()로 SettingWithCopyWarning 방지
    if sub.empty:
        continue

    # ---- 카테고리 집중도 ----
    cat_summary = (
        sub.groupby('category', dropna=False)['carbon']
        .sum()
        .sort_values(ascending=False)
    )
    total_carbon = sub['carbon'].sum()

    if cat_summary.empty:
        top_category = '기타'
        cat_focus_ratio = 0
    else:
        top_category = cat_summary.index[0]
        cat_focus_ratio = sdiv(cat_summary.iloc[0], total_carbon)

    # ---- 브랜드 반복성 ----
    brand_counts = sub['merchant'].value_counts()
    if brand_counts.empty:
        top_brand = ''
        brand_repeat_ratio = 0
    else:
        top_brand = brand_counts.index[0]
        brand_repeat_ratio = sdiv(brand_counts.iloc[0], len(sub))

    # ---- 탄소 민감도 (amount=0 방어) ----
    sub['carbon_per_amount'] = sub.apply(lambda r: sdiv(r['carbon'], r['amount']), axis=1)
    carbon_sensitivity = sub['carbon_per_amount'].mean(skipna=True)
    if pd.isna(carbon_sensitivity):
        carbon_sensitivity = 0

    # ---- 탄소 집중도 (Pareto 20%) ----
    n_top = max(1, math.ceil(len(sub) * 0.2))
    top_20 = sub.nlargest(n_top, 'carbon')
    carbon_concentration = sdiv(top_20['carbon'].sum(), total_carbon)

    # ---- 여가 소비 비율 (시간 사용 X, 카테고리만) ----
    leisure_ratio = sdiv(sub['category'].isin(LEISURE_CATS).sum(), len(sub))

    summary_list.append({
        "memberId": int(member_id),
        "총거래수": int(len(sub)),
        "총탄소배출": round(float(total_carbon), 2),
        "탄소주요카테고리": top_category,
        "카테고리집중도": round(float(cat_focus_ratio), 2),
        "주요브랜드": top_brand,
        "브랜드반복성": round(float(brand_repeat_ratio), 2),
        "탄소민감도": round(float(carbon_sensitivity), 3),
        "탄소집중도(Pareto20)": round(float(carbon_concentration), 2),
        "여가소비비율": round(float(leisure_ratio), 2),
    })

df_summary = pd.DataFrame(summary_list)

# ============== 행동 유형 분류 (주말 관련 조건 제거) ==============
def classify_motivation(row):
    if row['여가소비비율'] >= 0.6 and row['탄소민감도'] >= 0.1:
        return "🎯 여가-탄소 과다형"
    elif row['브랜드반복성'] >= 0.3 and row['탄소주요카테고리'] in ['대형마트', '편의점']:
        return "🔁 루틴 소비형"
    elif row['탄소민감도'] >= 0.15 and row['탄소집중도(Pareto20)'] <= 0.35:
        return "🎯 탄소 민감형"
    elif row['탄소집중도(Pareto20)'] >= 0.5:
        return "🎲 소비 편중형"
    else:
        return "🎭 혼합형"

df_summary["행동동기유형"] = df_summary.apply(classify_motivation, axis=1)

df_summary
# Out:
#    memberId  총거래수     총탄소배출 탄소주요카테고리  카테고리집중도     주요브랜드  브랜드반복성  탄소민감도  \
# 0         1   100   9734.63     대형마트     0.64     세븐일레븐    0.33  0.006
# 1         2   100  10436.54       카페     0.57  (주)에이비카페    0.21  0.011
# 2         3   100  10661.93    문화,예술     0.35     롯데시네마    0.34  0.005
# 3         4   100  24699.96    의료,건강     0.85    톡스앤필의원    0.44  0.005
# 4         5   100  77077.81    교통,수송     0.83    오렌지주유소    0.36  0.012
# 5         6   100  21743.98    교통,수송     0.25       이마트    0.09  0.007
# 6         7   100  12768.80       카페     0.46  (주)에이비카페    0.25  0.010
# 7         8   100   8956.82     대형마트     0.54     롯데시네마    0.23  0.005
# 8         9   100  19967.32       숙박     0.44       CGV    0.23  0.006
# 9        10   100  31500.05    교통,수송     0.70     세븐일레븐    0.23  0.008
#
#    탄소집중도(Pareto20)  여가소비비율    행동동기유형
# 0             0.55    0.07  🔁 루틴 소비형
# 1             0.35    0.96     🎭 혼합형
# 2             0.58    0.86  🎲 소비 편중형
# 3             0.49    0.11     🎭 혼합형
# 4             0.55    0.09  🎲 소비 편중형
# 5             0.68    0.45  🎲 소비 편중형
# 6             0.46    0.75     🎭 혼합형
# 7             0.55    0.42  🎲 소비 편중형
# 8             0.72    0.85  🎲 소비 편중형
# 9             0.79    0.14  🎲 소비 편중형

# %%
# 소비항목 기여도 분석 (merchant 단위)
def get_merchant_summary(df_user):
    merchant_summary = df_user.groupby('merchant').agg({
        'carbon': 'sum',
        'amount': 'sum',
        'category': 'first'  # 대표 카테고리 표시용
    }).reset_index()

    total_carbon = df_user['carbon'].sum()
    merchant_summary['carbon_ratio'] = merchant_summary['carbon'] / total_carbon
    merchant_summary['carbon_intensity'] = merchant_summary['carbon'] / merchant_summary['amount']
    merchant_summary = merchant_summary.sort_values('carbon_ratio', ascending=False)

    return merchant_summary

# %%
def get_merchant_summary(df_user):
    merchant_summary = df_user.groupby('merchant').agg({
        'carbon': 'sum',
        'amount': 'sum',
        'category': 'first'
    }).reset_index()

    # ✅ 전체 합이 정확히 1이 되게
    total_carbon = merchant_summary['carbon'].sum()

    merchant_summary['carbon_ratio'] = merchant_summary['carbon'] / total_carbon
    merchant_summary['carbon_intensity'] = merchant_summary['carbon'] / merchant_summary['amount']
    merchant_summary = merchant_summary.sort_values('carbon_ratio', ascending=False)

    return merchant_summary


def score_reduction_targets(merchant_df, user_summary_row):
    """
    merchant_df: get_merchant_summary로 나온 df
    user_summary_row: df_summary에서 한 사람의 row (Series)
    """
    leisure_categories = ['카페', '음식점', '문화시설']

    scores = []
    for _, row in merchant_df.iterrows():
        score = 0
        explanation = []

        # 1. 탄소 기여도 (weight 0.4)
        score += row['carbon_ratio'] * 0.4
        explanation.append(f"탄소기여도 +{round(row['carbon_ratio']*0.4, 3)}")

        # 2. 탄소 단가 (weight 0.2)
        score += row['carbon_intensity'] * 0.2
        explanation.append(f"탄소단가 +{round(row['carbon_intensity']*0.2, 3)}")

        # 3. 여가 소비 여부 (weight 0.2)
        if row['category'] in leisure_categories:
            score += 0.2
            explanation.append("여가소비 +0.2")

        # 4. 브랜드 반복성 (weight -0.1 if 반복성 높음)
        if row['merchant'] == user_summary_row['주요브랜드']:
            repeat_penalty = -0.1 * user_summary_row['브랜드반복성']
            score += repeat_penalty
            explanation.append(f"브랜드반복성 패널티 {round(repeat_penalty,3)}")

        # 5. 행동동기유형 기반 penalty (예시: 루틴 소비형이면 생필품은 줄이기 어려움)
        if user_summary_row['행동동기유형'] == '🔁 루틴 소비형' and row['category'] in ['대형마트', '편의점']:
            score -= 0.15
            explanation.append("루틴소비형 - 생필품 감축저항 -0.15")

        scores.append({
            'merchant': row['merchant'],
            'category': row['category'],
            'carbon_ratio': round(row['carbon_ratio'], 3),
            'carbon_intensity': round(row['carbon_intensity'], 3),
            '감축우선순위점수': round(score, 4),
            '설명': " / ".join(explanation)
        })

    return pd.DataFrame(scores).sort_values('감축우선순위점수', ascending=False)




# 1번 사용자 데이터 분석
df_user1 = df[df['memberId'] == 1]
merchant_df1 = get_merchant_summary(df_user1)

# 요약 테이블에서 1번 사용자 row 가져오기
row_user1 = df_summary[df_summary['memberId'] == 1].iloc[0]

# 감축 타겟 점수 계산
priority_df = score_reduction_targets(merchant_df1, row_user1)
priority_df
# Out:
#    merchant category  carbon_ratio  carbon_intensity  감축우선순위점수  \
# 5      맥도날드      음식점         0.021             0.011    0.2105
# 6  (주)에이비카페       카페         0.016             0.011    0.2087
# 7       쿰베오       카페         0.013             0.011    0.2072
# 4       정약국    의료,건강         0.025             0.004    0.0109
# 8       CGV    문화,예술         0.008             0.003    0.0036
# 9     롯데시네마    문화,예술         0.007             0.003    0.0034
# 0      코스트코     대형마트         0.376             0.006    0.0015
# 1       이마트     대형마트         0.263             0.006   -0.0435
# 3      GS25      편의점         0.118             0.006   -0.1017
# 2     세븐일레븐      편의점         0.153             0.006   -0.1205
#
#                                                   설명
# 5             탄소기여도 +0.008 / 탄소단가 +0.002 / 여가소비 +0.2
# 6             탄소기여도 +0.006 / 탄소단가 +0.002 / 여가소비 +0.2
# 7             탄소기여도 +0.005 / 탄소단가 +0.002 / 여가소비 +0.2
# 4                          탄소기여도 +0.01 / 탄소단가 +0.001
# 8                         탄소기여도 +0.003 / 탄소단가 +0.001
# 9                         탄소기여도 +0.003 / 탄소단가 +0.001
# 0  탄소기여도 +0.15 / 탄소단가 +0.001 / 루틴소비형 - 생필품 감축저항 -...
# 1  탄소기여도 +0.105 / 탄소단가 +0.001 / 루틴소비형 - 생필품 감축저항 ...
# 3  탄소기여도 +0.047 / 탄소단가 +0.001 / 루틴소비형 - 생필품 감축저항 ...
# 2  탄소기여도 +0.061 / 탄소단가 +0.001 / 브랜드반복성 패널티 -0.033...

# %%
def recommend_reduction_range(user_df, merchant_name):

    df_merchant = user_df[user_df['merchant'] == merchant_name]

    if len(df_merchant) < 3:
        return {
            "range": (0, 10),
            "reason": "해당 브랜드의 소비 기록이 적어, 안전하게 0~10% 감축만 권장됩니다."
        }

    # 월별 소비 추이 분석 (예시: 금액 기준)
    monthly = df_merchant.groupby(df_merchant['date'].dt.to_period('M'))['amount'].sum()
    std_ratio = monthly.std() / (monthly.mean() + 1e-6)

    # std_ratio → 감축 가능 범위 추정
    if std_ratio > 0.7:
        r = (20, 80)
        reason = f"소비 변동성이 매우 크기 때문에, 최대 80%까지도 감축 가능합니다. (표준편차비: {std_ratio:.2f})"
    elif std_ratio > 0.4:
        r = (10, 40)
        reason = f"소비 변동성이 중간 수준이며, 10~40% 범위 감축이 가능합니다. (표준편차비: {std_ratio:.2f})"
    else:
        r = (0, 15)
        reason = f"소비가 매우 일정하여 감축 여지가 낮습니다. (표준편차비: {std_ratio:.2f})"

    return {
        "range": r,
        "reason": reason
    }

def analyze_top_reduction_targets(df_user, df_summary, member_id, top_n=5):

    # 개별 사용자 데이터 추출
    df_user_indiv = df_user[df_user['memberId'] == member_id]
    row_user = df_summary[df_summary['memberId'] == member_id].iloc[0]

    # 1. merchant summary
    merchant_df = get_merchant_summary(df_user_indiv)

    # 2. 감축우선순위 점수 계산
    priority_df = score_reduction_targets(merchant_df, row_user)

    # 3. 상위 N개 merchant에 대해 감축률 추천
    reduction_infos = []
    for _, row in priority_df.head(top_n).iterrows():
        merchant_name = row['merchant']
        reduction = recommend_reduction_range(df_user_indiv, merchant_name)

        reduction_infos.append({
            "merchant": merchant_name,
            "category": row['category'],
            "carbon_ratio": row['carbon_ratio'],
            "감축우선순위점수": row['감축우선순위점수'],
            "감축률_추천범위": f"{reduction['range'][0]}% ~ {reduction['range'][1]}%",
            "감축률_추천_이유": reduction['reason'],
            "설명": row['설명']
        })

    return pd.DataFrame(reduction_infos)


top_reduction_df = analyze_top_reduction_targets(df, df_summary, member_id=1, top_n=5)
top_reduction_df
# Out:
#    merchant category  carbon_ratio  감축우선순위점수   감축률_추천범위  \
# 0      맥도날드      음식점         0.021    0.2105   0% ~ 10%
# 1  (주)에이비카페       카페         0.016    0.2087   0% ~ 10%
# 2       쿰베오       카페         0.013    0.2072   0% ~ 10%
# 3       정약국    의료,건강         0.025    0.0109  10% ~ 40%
# 4       CGV    문화,예술         0.008    0.0036   0% ~ 10%
#
#                                            감축률_추천_이유  \
# 0           해당 브랜드의 소비 기록이 적어, 안전하게 0~10% 감축만 권장됩니다.
# 1           해당 브랜드의 소비 기록이 적어, 안전하게 0~10% 감축만 권장됩니다.
# 2           해당 브랜드의 소비 기록이 적어, 안전하게 0~10% 감축만 권장됩니다.
# 3  소비 변동성이 중간 수준이며, 10~40% 범위 감축이 가능합니다. (표준편차비: ...
# 4           해당 브랜드의 소비 기록이 적어, 안전하게 0~10% 감축만 권장됩니다.
#
#                                        설명
# 0  탄소기여도 +0.008 / 탄소단가 +0.002 / 여가소비 +0.2
# 1  탄소기여도 +0.006 / 탄소단가 +0.002 / 여가소비 +0.2
# 2  탄소기여도 +0.005 / 탄소단가 +0.002 / 여가소비 +0.2
# 3               탄소기여도 +0.01 / 탄소단가 +0.001
# 4              탄소기여도 +0.003 / 탄소단가 +0.001

# %% [markdown]
# # LLM 기반 탄소 감축 전략 액션 플랜 제공

# %%
# -*- coding: utf-8 -*-
import os
import json
import requests
from dotenv import load_dotenv

# 환경변수에서 API Key 로드
load_dotenv()
API_KEY  = os.getenv("GEMINI_API_KEY")
MODEL_ID = "gemini-2.5-flash"
ENDPOINT = (
    f"https://generativelanguage.googleapis.com/v1beta/models/"
    f"{MODEL_ID}:generateContent?key=AIzaSyAtHIIhgWL3Xam5OHWV0WblQUMW2VgnUdM"
)

def call_gemini_api(prompt: str, temperature: float = 0.0, max_tokens: int = 4096) -> str:

    payload = {
        "contents": [
            {"parts": [{"text": prompt}]}
        ],
        "generationConfig": {
            "temperature": temperature,
            "maxOutputTokens": max_tokens,
            "thinkingConfig": {"thinkingBudget": 0}
        }
    }
    body = json.dumps(payload, ensure_ascii=False).encode("utf-8")
    headers = {"Content-Type": "application/json; charset=utf-8"}

    resp = requests.post(ENDPOINT, headers=headers, data=body)
    resp.raise_for_status()
    return resp.json()["candidates"][0]["content"]["parts"][0]["text"]

# ──────────────────────────────
# 소비자별 요약 + LLM 프롬프트 생성 및 호출
# ──────────────────────────────
def summarize_user_targets_and_ask_llm(member_id, df_user, df_summary, top_n=5):
    """
    감축우선순위 기반 추천 + Gemini 프롬프트 생성 및 호출
    """
    # 1. 사용자 데이터 정리
    df_user_indiv = df_user[df_user['memberId'] == member_id]
    total_amount = df_user_indiv["amount"].sum()
    total_carbon = df_user_indiv["carbon"].sum()

    # 2. 감축 타겟 분석
    df_targets = analyze_top_reduction_targets(df_user, df_summary, member_id, top_n=top_n)

    # 3. 프롬프트 구성
    summary_lines = [
        f"소비자 {member_id}의 한 달 소비 요약:",
        f"- 총 지출: {round(total_amount,1)}원, 총 탄소 배출: {round(total_carbon,1)}kgCO₂",
        f"- 탄소 감축 우선순위 Top {top_n} 항목:"
    ]

    for _, row in df_targets.iterrows():
        summary_lines.append(
            f"• {row['merchant']} ({row['category']}): "
            f"탄소기여도 {round(row['carbon_ratio']*100, 1)}%, "
            f"감축우선순위 점수 {round(row['감축우선순위점수'], 3)}, "
            f"추천 감축률 {row['감축률_추천범위']} → 이유: {row['감축률_추천_이유']}"
        )

    summary_lines.append("\n이 소비자에게 탄소 감축을 위해 어떤 실천 전략이 가장 효과적일까요?")
    summary_lines.append("항목별로 감축률을 선택할 수 있게 유도하고, 총 감축 효과가 얼마나 될지도 예측해주세요.")
    summary_lines.append("다음과 같은 형식에 맞춰 구체적으로 답변해 주세요. 반드시 아래 구조를 따르되, 내용은 소비자 특성에 맞게 맞춤화해 주세요:\n")
    summary_lines.append("""
    1. 소비자 인삿말 및 분석 요약

    2. [현재 소비 패턴 분석]
    - 총지출 대비 탄소 배출량 특이점
    - 어떤 업종/브랜드가 주요 기여자인지
    - 탄소 감축 가능성이 있는 소비 패턴
    - 추천 감축률이 낮은 이유 (ex: 소비 기록 적음)

    3. [감축 전략 제안]
    - 외식/문화 등 업종별 구체적 조언 포함
    - 실천 가능한 행동 위주로 제안

    4. [Top 5 항목별 감축률 가이드]
    아래 형식을 반복해서 제시:
    - 브랜드명 (업종)
    - 현재 탄소 기여도 (kgCO₂)
    - 추천 감축률 (예: 0% / 5% / 10% / 20% / 30%)
    - 실천 전략 (bullet 2~3개)
    - 감축률별 감축 예상량 (계산 기반)

    5. [총 감축 효과 예측]
    - 예시 시나리오 제시
    - 각 항목 감축률 선택 + 총 감축량 계산
    - 감축 후 총 배출량 제시

    6. [마무리 코멘트]
    - 긍정적인 격려
    - 다음 단계 제안

    **반드시 위 양식을 지켜 작성해주세요.**""")

    prompt = "\n".join(summary_lines)

    print(f"\n[Gemini 프롬프트 - member {member_id}]\n{prompt}\n")

    # Gemini API 호출
    response = call_gemini_api(prompt)
    print(f"[Gemini 응답 - member {member_id}]\n{response}\n{'-'*50}")

# ──────────────────────────────
# 전체 실행

if __name__ == "__main__":
    # memberId별로 루프 돌며 Gemini 호출
    for member_id in df["memberId"].unique():
        summarize_user_targets_and_ask_llm(member_id, df, df_summary, top_n=5)
# Out:
# [Gemini 프롬프트 - member 1]
# 소비자 1의 한 달 소비 요약:
# - 총 지출: 1715102원, 총 탄소 배출: 9734.6kgCO₂
# - 탄소 감축 우선순위 Top 5 항목:
# • 맥도날드 (음식점): 탄소기여도 2.1%, 감축우선순위 점수 0.21, 추천 감축률 0% ~ 10% → 이유: 해당 브랜드의 소비 기록이 적어, 안전하게 0~10% 감축만 권장됩니다.
# • (주)에이비카페 (카페): 탄소기여도 1.6%, 감축우선순위 점수 0.209, 추천 감축률 0% ~ 10% → 이유: 해당 브랜드의 소비 기록이 적어, 안전하게 0~10% 감축만 권장됩니다.
# • 쿰베오 (카페): 탄소기여도 1.3%, 감축우선순위 점수 0.207, 추천 감축률 0% ~ 10% → 이유: 해당 브랜드의 소비 기록이 적어, 안전하게 0~10% 감축만 권장됩니다.
# • 정약국 (의료,건강): 탄소기여도 2.5%, 감축우선순위 점수 0.011, 추천 감축률 10% ~ 40% → 이유: 소비 변동성이 중간 수준이며, 10~40% 범위 감축이 가능합니다. (표준편차비: 0.55)
# • CGV (문화,예술): 탄소기여도 0.8%, 감축우선순위 점수 0.004, 추천 감축률 0% ~ 10% → 이유: 해당 브랜드의 소비 기록이 적어, 안전하게 0~10% 감축만 권장됩니다.
#
# 이 소비자에게 탄소 감축을 위해 어떤 실천 전략이 가장 효과적일까요?
# 항목별로 감축률을 선택할 수 있게 유도하고, 총 감축 효과가 얼마나 될지도 예측해주세요.
# 다음과 같은 형식에 맞춰 구체적으로 답변해 주세요. 반드시 아래 구조를 따르되, 내용은 소비자 특성에 맞게 맞춤화해 주세요:
#
#
#     1. 소비자 인삿말 및 분석 요약
#
#     2. [현재 소비 패턴 분석]
#     - 총지출 대비 탄소 배출량 특이점
#     - 어떤 업종/브랜드가 주요 기여자인지
#     - 탄소 감축 가능성이 있는 소비 패턴
#     - 추천 감축률이 낮은 이유 (ex: 소비 기록 적음)
#
#     3. [감축 전략 제안]
#     - 외식/문화 등 업종별 구체적 조언 포함
#     - 실천 가능한 행동 위주로 제안
#
#     4. [Top 5 항목별 감축률 가이드]
#     아래 형식을 반복해서 제시:
#     - 브랜드명 (업종)
#     - 현재 탄소 기여도 (kgCO₂)
#     - 추천 감축률 (예: 0% / 5% / 10% / 20% / 30%)
#     - 실천 전략 (bullet 2~3개)
#     - 감축률별 감축 예상량 (계산 기반)
#
#     5. [총 감축 효과 예측]
#     - 예시 시나리오 제시
#     - 각 항목 감축률 선택 + 총 감축량 계산
#     - 감축 후 총 배출량 제시
#
#     6. [마무리 코멘트]
#     - 긍정적인 격려
#     - 다음 단계 제안
#
#     **반드시 위 양식을 지켜 작성해주세요.**
#
# [Gemini 응답 - member 1]
# ## 1. 소비자 인삿말 및 분석 요약
#
# 안녕하세요, 소비자님! 한 달간의 소비 데이터를 바탕으로 탄소 배출 현황을 분석해 드립니다. 총 지출 1,715,102원에 총 탄소 배출량은 9,734.6kgCO₂로 나타났습니다. 현재 소비 패턴을 분석하여 탄소 감축을 위한 효과적인 전략을 제안해 드리고자 합니다.
#
# ## 2. [현재 소비 패턴 분석]
#
# *   **총지출 대비 탄소 배출량 특이점**: 소비자님의 총 지출액 대비 탄소 배출량은 9,734.6kgCO₂로, 이는 일반적인 소비 활동에서 발생하는 탄소 배출량과 비교했을 때 다소 높은 수준으로 보입니다. 특히 특정 업종에서의 소비가 탄소 배출에 큰 영향을 미치고 있을 가능성이 있습니다.
#
# *   **어떤 업종/브랜드가 주요 기여자인지**: 현재 데이터만으로는 특정 업종이 압도적인 기여를 한다고 단정하기는 어렵습니다. 다만, '정약국'이 탄소 기여도 2.5%로 가장 높은 기여도를 보이고 있으며, '맥도날드', '(주)에이비카페', '쿰베오' 등 외식/카페 업종이 그 뒤를 잇고 있습니다. 이는 다양한 브랜드에서 소액의 소비가 누적되어 전체 탄소 배출에 영향을 미치고 있음을 시사합니다.
#
# *   **탄소 감축 가능성이 있는 소비 패턴**: '정약국'의 경우 소비 변동성이 중간 수준으로 나타나 10%~40%의 감축이 가능하다고 분석되었습니다. 이는 의료/건강 관련 소비에서 불필요한 지출을 줄이거나, 대체 가능한 친환경적인 방법을 모색함으로써 탄소 감축을 이룰 수 있음을 의미합니다.
#
# *   **추천 감축률이 낮은 이유 (ex: 소비 기록 적음)**: '맥도날드', '(주)에이비카페', '쿰베오', 'CGV'와 같은 브랜드들은 현재 소비 기록이 적어 안전하게 0%~10%의 낮은 감축률만 권장되었습니다. 이는 해당 브랜드에서의 소비가 일회성이거나, 아직 충분한 데이터가 축적되지 않아 소비 패턴을 명확히 파악하기 어렵기 때문입니다. 앞으로 소비 기록이 더 쌓이면 보다 정확한 감축률을 제안해 드릴 수 있을 것입니다.
#
# ## 3. [감축 전략 제안]
#
# 소비자님의 소비 패턴을 고려할 때, 탄소 감축을 위한 전략은 크게 두 가지 방향으로 제안할 수 있습니다.
#
# *   **외식/카페 업종**:
#     *   **불필요한 외식 줄이기**: 맥도날드, 카페 등 외식 빈도를 줄이고 집에서 직접 요리하는 횟수를 늘려보세요. 외식 시에는 채식 메뉴를 선택하거나, 포장 용기를 재활용 가능한 것으로 선택하는 것도 좋은 방법입니다.
#     *   **개인 컵 사용 생활화**: 카페 이용 시 개인 컵을 사용하면 일회용 컵 사용을 줄여 탄소 배출을 줄일 수 있습니다. 많은 카페에서 개인 컵 사용 시 할인 혜택을 제공하기도 합니다.
#     *   **로컬 푸드 및 제철 음식 소비**: 지역 농산물이나 제철 음식을 소비하면 식재료 운송 과정에서 발생하는 탄소 배출을 줄일 수 있습니다.
#
# *   **의료/건강 업종**:
#     *   **불필요한 약 구매 줄이기**: 정약국 이용 시, 정말 필요한 약만 구매하고 불필요한 약은 줄이는 습관을 들여보세요.
#     *   **건강 관리 습관 개선**: 꾸준한 운동과 건강한 식단으로 질병 예방에 힘써 병원 방문 및 약 구매를 줄이는 것도 장기적인 탄소 감축에 도움이 됩니다.
#
# *   **문화/예술 업종**:
#     *   **대중교통 이용**: CGV 등 문화 시설 방문 시 자가용 대신 대중교통을 이용하면 이동 과정에서 발생하는 탄소 배출을 줄일 수 있습니다.
#     *   **온라인 콘텐츠 활용**: 영화관 방문 대신 OTT 서비스 등 온라인 콘텐츠를 활용하는 것도 탄소 배출을 줄이는 한 가지 방법입니다.
#
# ## 4. [Top 5 항목별 감축률 가이드]
#
# 아래는 소비자님의 탄소 감축 우선순위 Top 5 항목에 대한 감축률 가이드입니다. 각 항목별로 실천 가능한 전략과 예상 감축량을 확인해 보세요.
#
# *   **맥도날드 (음식점)**
#     *   현재 탄소 기여도: 204.4kgCO₂ (9734.6kgCO₂ * 2.1%)
#     *   추천 감축률: 0% / 5% / 10%
#     *   실천 전략:
#         *   주 1회 맥도날드 방문을 2주 1회로 줄이기
#         *   맥도날드 방문 시 채식 버거 등 저탄소 메뉴 선택
#         *   집에서 직접 햄버거 만들어 먹기
#     *   감축률별 감축 예상량:
#         *   0% 감축: 0kgCO₂
#         *   5% 감축: 10.22kgCO₂
#         *   10% 감축: 20.44kgCO₂
#
# *   **(주)에이비카페 (카페)**
#     *   현재 탄소 기여도: 155.75kgCO₂ (9734.6kgCO₂ * 1.6%)
#     *   추천 감축률: 0% / 5% / 10%
#     *   실천 전략:
#         *   카페 방문 시 개인 컵 사용 생활화
#         *   테이크아웃 대신 매장 내에서 머그컵 이용
#         *   집에서 직접 커피 내려 마시기
#     *   감축률별 감축 예상량:
#         *   0% 감축: 0kgCO₂
#         *   5% 감축: 7.79kgCO₂
#         *   10% 감축: 15.58kgCO₂
#
# *   **쿰베오 (카페)**
#     *   현재 탄소 기여도: 126.55kgCO₂ (9734.6kgCO₂ * 1.3%)
#     *   추천 감축률: 0% / 5% / 10%
#     *   실천 전략:
#         *   카페 방문 시 개인 컵 사용 생활화
#         *   테이크아웃 대신 매장 내에서 머그컵 이용
#         *   집에서 직접 커피 내려 마시기
#     *   감축률별 감축 예상량:
#         *   0% 감축: 0kgCO₂
#         *   5% 감축: 6.33kgCO₂
#         *   10% 감축: 12.66kgCO₂
#
# *   **정약국 (의료,건강)**
#     *   현재 탄소 기여도: 243.37kgCO₂ (9734.6kgCO₂ * 2.5%)
#     *   추천 감축률: 10% / 20% / 30% / 40%
#     *   실천 전략:
#         *   불필요한 약 구매 줄이기 (예: 상비약 재고 확인 후 구매)
#         *   가벼운 증상은 자연 치유 또는 생활 습관 개선으로 관리
#         *   정기적인 건강 검진으로 질병 예방
#     *   감축률별 감축 예상량:
#         *   10% 감축: 24.34kgCO₂
#         *   20% 감축: 48.67kgCO₂
#         *   30% 감축: 73.01kgCO₂
#         *   40% 감축: 97.35kgCO₂
#
# *   **CGV (문화,예술)**
#     *   현재 탄소 기여도: 77.88kgCO₂ (9734.6kgCO₂ * 0.8%)
#     *   추천 감축률: 0% / 5% / 10%
#     *   실천 전략:
#         *   영화관 방문 시 대중교통 이용
#         *   온라인 스트리밍 서비스 활용 빈도 늘리기
#         *   영화관 방문 횟수 줄이기 (예: 월 2회에서 월 1회로)
#     *   감축률별 감축 예상량:
#         *   0% 감축: 0kgCO₂
#         *   5% 감축: 3.89kgCO₂
#         *   10% 감축: 7.79kgCO₂
#
# ## 5. [총 감축 효과 예측]
#
# 소비자님께서 위 가이드를 바탕으로 각 항목의 감축률을 선택했을 때의 총 감축 효과를 예측해 드립니다.
#
# **예시 시나리오: 적극적인 감축 노력**
#
# *   **맥도날드**: 10% 감축 (20.44kgCO₂)
# *   **(주)에이비카페**: 10% 감축 (15.58kgCO₂)
# *   **쿰베오**: 10% 감축 (12.66kgCO₂)
# *   **정약국**: 30% 감축 (73.01kgCO₂)
# *   **CGV**: 10% 감축 (7.79kgCO₂)
#
# **총 감축량 계산:**
# 20.44 + 15.58 + 12.66 + 73.01 + 7.79 = **129.48kgCO₂**
#
# **감축 후 총 배출량:**
# 9734.6kgCO₂ - 129.48kgCO₂ = **9605.12kgCO₂**
#
# 이 시나리오대로 실천하시면 한 달에 약 129.48kgCO₂의 탄소를 감축하여 총 탄소 배출량을 9605.12kgCO₂로 줄일 수 있습니다. 이는 약 13그루의 소나무가 1년간 흡수하는 탄소량과 맞먹는 효과입니다!
#
# ## 6. [마무리 코멘트]
#
# 소비자님의 작은 실천들이 모여 지구를 위한 큰 변화를 만들 수 있습니다. 처음부터 모든 것을 바꾸려 하기보다는, 오늘 제안해 드린 항목들 중 가장 실천하기 쉬운 것부터 하나씩 시작해 보세요. 꾸준히 노력하시면 분명 의미 있는 탄소 감축 효과를 보실 수 있을 것입니다.
#
# 다음 달에도 소비 데이터를 분석하여 더욱 맞춤화된 탄소 감축 전략을 제안해 드리겠습니다. 지속적인 관심과 참여 부탁드립니다!
# --------------------------------------------------
#
# [Gemini 프롬프트 - member 2]
# 소비자 2의 한 달 소비 요약:
# - 총 지출: 982572원, 총 탄소 배출: 10436.5kgCO₂
# - 탄소 감축 우선순위 Top 5 항목:
# • 런던베이글 (음식점): 탄소기여도 17.8%, 감축우선순위 점수 0.273, 추천 감축률 20% ~ 80% → 이유: 소비 변동성이 매우 크기 때문에, 최대 80%까지도 감축 가능합니다. (표준편차비: 0.78)
# • 메가커피 (카페): 탄소기여도 14.3%, 감축우선순위 점수 0.259, 추천 감축률 10% ~ 40% → 이유: 소비 변동성이 중간 수준이며, 10~40% 범위 감축이 가능합니다. (표준편차비: 0.61)
# • 쿰베오 (카페): 탄소기여도 13.3%, 감축우선순위 점수 0.256, 추천 감축률 10% ~ 40% → 이유: 소비 변동성이 중간 수준이며, 10~40% 범위 감축이 가능합니다. (표준편차비: 0.41)
# • (주)에이비카페 (카페): 탄소기여도 18.2%, 감축우선순위 점수 0.254, 추천 감축률 0% ~ 15% → 이유: 소비가 매우 일정하여 감축 여지가 낮습니다. (표준편차비: 0.16)
# • 더벤티 (카페): 탄소기여도 11.6%, 감축우선순위 점수 0.249, 추천 감축률 10% ~ 40% → 이유: 소비 변동성이 중간 수준이며, 10~40% 범위 감축이 가능합니다. (표준편차비: 0.49)
#
# 이 소비자에게 탄소 감축을 위해 어떤 실천 전략이 가장 효과적일까요?
# 항목별로 감축률을 선택할 수 있게 유도하고, 총 감축 효과가 얼마나 될지도 예측해주세요.
# 다음과 같은 형식에 맞춰 구체적으로 답변해 주세요. 반드시 아래 구조를 따르되, 내용은 소비자 특성에 맞게 맞춤화해 주세요:
#
#
#     1. 소비자 인삿말 및 분석 요약
#
#     2. [현재 소비 패턴 분석]
#     - 총지출 대비 탄소 배출량 특이점
#     - 어떤 업종/브랜드가 주요 기여자인지
#     - 탄소 감축 가능성이 있는 소비 패턴
#     - 추천 감축률이 낮은 이유 (ex: 소비 기록 적음)
#
#     3. [감축 전략 제안]
#     - 외식/문화 등 업종별 구체적 조언 포함
#     - 실천 가능한 행동 위주로 제안
#
#     4. [Top 5 항목별 감축률 가이드]
#     아래 형식을 반복해서 제시:
#     - 브랜드명 (업종)
#     - 현재 탄소 기여도 (kgCO₂)
#     - 추천 감축률 (예: 0% / 5% / 10% / 20% / 30%)
#     - 실천 전략 (bullet 2~3개)
#     - 감축률별 감축 예상량 (계산 기반)
#
#     5. [총 감축 효과 예측]
#     - 예시 시나리오 제시
#     - 각 항목 감축률 선택 + 총 감축량 계산
#     - 감축 후 총 배출량 제시
#
#     6. [마무리 코멘트]
#     - 긍정적인 격려
#     - 다음 단계 제안
#
#     **반드시 위 양식을 지켜 작성해주세요.**
#
# [Gemini 응답 - member 2]
# ## 1. 소비자 인삿말 및 분석 요약
#
# 안녕하세요, 소비자 2님! 한 달간의 소비 데이터를 분석한 결과, 총 982,572원을 지출하셨고, 이로 인해 10,436.5kgCO₂의 탄소가 배출된 것으로 나타났습니다. 특히 음식점과 카페 업종에서 탄소 배출 기여도가 높은 것으로 분석되었습니다.
#
# ## 2. [현재 소비 패턴 분석]
#
# *   **총지출 대비 탄소 배출량 특이점:** 총 지출액이 약 98만원으로 적지 않은 편이며, 이에 비례하여 탄소 배출량도 1만 kgCO₂를 넘어섰습니다. 이는 소비 활동이 환경에 미치는 영향이 상당함을 보여줍니다.
# *   **어떤 업종/브랜드가 주요 기여자인지:** 탄소 감축 우선순위 Top 5 항목을 보면, '런던베이글' (음식점)이 17.8%로 가장 높은 탄소 기여도를 보였고, 이어서 '메가커피', '쿰베오', '(주)에이비카페', '더벤티' 등 카페 업종이 높은 기여도를 차지하고 있습니다. 이는 외식 및 카페 이용이 탄소 배출의 주요 원인임을 시사합니다.
# *   **탄소 감축 가능성이 있는 소비 패턴:** '런던베이글'의 경우 소비 변동성이 매우 커서 최대 80%까지 감축이 가능하다고 분석되었습니다. 이는 특정 시기에 집중적으로 소비가 이루어졌거나, 대체 가능한 소비가 많다는 의미로 해석될 수 있습니다. 다른 카페 브랜드들도 중간 수준의 변동성을 보여 감축 여지가 있습니다.
# *   **추천 감축률이 낮은 이유 (ex: 소비 기록 적음):** '(주)에이비카페'의 경우 탄소 기여도가 18.2%로 높음에도 불구하고 추천 감축률이 0%~15%로 낮은 이유는 소비가 매우 일정하여 감축 여지가 적기 때문입니다. 이는 해당 브랜드에 대한 소비가 습관적이거나 필수적인 성격을 띠고 있을 가능성을 보여줍니다.
#
# ## 3. [감축 전략 제안]
#
# 소비자 2님의 탄소 감축을 위해 외식 및 카페 이용 습관에 초점을 맞춘 실천 가능한 전략을 제안합니다.
#
# *   **외식/음식점:**
#     *   **런던베이글:** 소비 변동성이 크므로, 방문 횟수를 줄이거나, 포장 대신 매장 내 식사를 선택하여 일회용품 사용을 줄이는 것을 고려해 보세요. 혹은 베이글 대신 탄소 배출량이 적은 다른 메뉴를 선택하는 것도 방법입니다.
#     *   **전반적인 외식:** 주 1회 외식 대신 집에서 직접 요리하는 날을 늘려보세요. 식재료 구매 시에는 로컬 푸드나 제철 식재료를 선택하여 운송 과정에서 발생하는 탄소를 줄일 수 있습니다.
# *   **카페:**
#     *   **메가커피, 쿰베오, 더벤티:** 개인 컵/텀블러를 사용하여 일회용 컵 사용을 줄이는 것이 가장 효과적인 방법입니다. 많은 카페에서 텀블러 할인 혜택을 제공하니 이를 활용해 보세요.
#     *   **'(주)에이비카페':** 소비가 일정하므로, 이곳에서 커피를 마실 때마다 텀블러를 사용하는 습관을 들이는 것만으로도 큰 감축 효과를 볼 수 있습니다.
#     *   **전반적인 카페 이용:** 불필요한 카페 방문을 줄이고, 집에서 직접 커피를 내려 마시는 습관을 들이는 것도 좋은 방법입니다.
#
# ## 4. [Top 5 항목별 감축률 가이드]
#
# 각 항목별로 추천 감축률을 선택하고, 그에 따른 예상 감축량을 확인해 보세요.
#
# *   **런던베이글 (음식점)**
#     *   현재 탄소 기여도: 1857.7kgCO₂ (총 10436.5kgCO₂의 17.8%)
#     *   추천 감축률: 0% / 20% / 40% / 60% / 80%
#     *   실천 전략:
#         *   방문 횟수를 주 1회에서 격주 1회로 줄이기
#         *   포장 대신 매장 내 식사 선택하여 일회용품 사용 줄이기
#         *   베이글 대신 탄소 배출량이 적은 다른 메뉴 선택 고려
#     *   감축률별 감축 예상량:
#         *   0% 선택 시: 0kgCO₂ 감축
#         *   20% 선택 시: 약 371.5kgCO₂ 감축
#         *   40% 선택 시: 약 743.1kgCO₂ 감축
#         *   60% 선택 시: 약 1114.6kgCO₂ 감축
#         *   80% 선택 시: 약 1486.2kgCO₂ 감축
#
# *   **메가커피 (카페)**
#     *   현재 탄소 기여도: 1492.9kgCO₂ (총 10436.5kgCO₂의 14.3%)
#     *   추천 감축률: 0% / 10% / 20% / 30% / 40%
#     *   실천 전략:
#         *   개인 컵/텀블러 사용 습관화 (텀블러 할인 혜택 활용)
#         *   주 1회 정도는 카페 방문 대신 집에서 커피 내려 마시기
#         *   불필요한 카페 방문 줄이기
#     *   감축률별 감축 예상량:
#         *   0% 선택 시: 0kgCO₂ 감축
#         *   10% 선택 시: 약 149.3kgCO₂ 감축
#         *   20% 선택 시: 약 298.6kgCO₂ 감축
#         *   30% 선택 시: 약 447.9kgCO₂ 감축
#         *   40% 선택 시: 약 597.2kgCO₂ 감축
#
# *   **쿰베오 (카페)**
#     *   현재 탄소 기여도: 1387.4kgCO₂ (총 10436.5kgCO₂의 13.3%)
#     *   추천 감축률: 0% / 10% / 20% / 30% / 40%
#     *   실천 전략:
#         *   개인 컵/텀블러 사용 습관화
#         *   카페 방문 시 대중교통 이용 또는 도보 이동
#         *   디저트류 소비 시 포장 대신 매장 내 식사 고려
#     *   감축률별 감축 예상량:
#         *   0% 선택 시: 0kgCO₂ 감축
#         *   10% 선택 시: 약 138.7kgCO₂ 감축
#         *   20% 선택 시: 약 277.5kgCO₂ 감축
#         *   30% 선택 시: 약 416.2kgCO₂ 감축
#         *   40% 선택 시: 약 555.0kgCO₂ 감축
#
# *   **(주)에이비카페 (카페)**
#     *   현재 탄소 기여도: 1898.4kgCO₂ (총 10436.5kgCO₂의 18.2%)
#     *   추천 감축률: 0% / 5% / 10% / 15%
#     *   실천 전략:
#         *   매번 개인 컵/텀블러 사용 (가장 효과적)
#         *   불필요한 추가 음료 구매 자제
#         *   테이크아웃 시 빨대 등 일회용품 거절
#     *   감축률별 감축 예상량:
#         *   0% 선택 시: 0kgCO₂ 감축
#         *   5% 선택 시: 약 94.9kgCO₂ 감축
#         *   10% 선택 시: 약 189.8kgCO₂ 감축
#         *   15% 선택 시: 약 284.8kgCO₂ 감축
#
# *   **더벤티 (카페)**
#     *   현재 탄소 기여도: 1210.6kgCO₂ (총 10436.5kgCO₂의 11.6%)
#     *   추천 감축률: 0% / 10% / 20% / 30% / 40%
#     *   실천 전략:
#         *   개인 컵/텀블러 사용 습관화
#         *   대용량 음료 대신 적정량 음료 선택
#         *   음료 주문 시 얼음 양 조절하여 불필요한 소비 줄이기
#     *   감축률별 감축 예상량:
#         *   0% 선택 시: 0kgCO₂ 감축
#         *   10% 선택 시: 약 121.1kgCO₂ 감축
#         *   20% 선택 시: 약 242.1kgCO₂ 감축
#         *   30% 선택 시: 약 363.2kgCO₂ 감축
#         *   40% 선택 시: 약 484.2kgCO₂ 감축
#
# ## 5. [총 감축 효과 예측]
#
# 소비자 2님께서 위 가이드를 바탕으로 각 항목의 감축률을 선택했을 때의 총 감축 효과를 예측해 보겠습니다.
#
# **예시 시나리오:**
#
# *   **런던베이글:** 40% 감축 선택 (743.1kgCO₂ 감축)
# *   **메가커피:** 20% 감축 선택 (298.6kgCO₂ 감축)
# *   **쿰베오:** 20% 감축 선택 (277.5kgCO₂ 감축)
# *   **(주)에이비카페:** 10% 감축 선택 (189.8kgCO₂ 감축)
# *   **더벤티:** 20% 감축 선택 (242.1kgCO₂ 감축)
#
# **총 감축량 계산:**
# 743.1 + 298.6 + 277.5 + 189.8 + 242.1 = **1751.1kgCO₂**
#
# **감축 후 총 배출량:**
# 10436.5kgCO₂ (기존) - 1751.1kgCO₂ (감축) = **8685.4kgCO₂**
#
# 이 시나리오대로 실천하시면 한 달에 약 1751.1kgCO₂의 탄소를 감축하여, 총 탄소 배출량을 8685.4kgCO₂로 줄일 수 있습니다. 이는 기존 배출량 대비 약 16.8%의 감축 효과입니다.
#
# ## 6. [마무리 코멘트]
#
# 소비자 2님, 탄소 감축을 위한 첫걸음을 내딛는 것은 매우 의미 있는 일입니다. 위에서 제안 드린 전략들을 꾸준히 실천하시면 환경 보호에 크게 기여하실 수 있습니다. 처음부터 모든 것을 바꾸려 하기보다는, 실천 가능한 작은 변화부터 시작하여 점차 늘려나가는 것이 중요합니다.
#
# 다음 달에는 감축된 탄소 배출량을 함께 확인하고, 더 나아가 다른 소비 항목에서도 탄소 감축 기회를 찾아보는 시간을 가질 수 있기를 바랍니다. 소비자 2님의 지속적인 노력과 관심에 감사드립니다!
# --------------------------------------------------
#
# [Gemini 프롬프트 - member 3]
# 소비자 3의 한 달 소비 요약:
# - 총 지출: 2301630원, 총 탄소 배출: 10661.9kgCO₂
# - 탄소 감축 우선순위 Top 5 항목:
# • (주)에이비카페 (카페): 탄소기여도 9.4%, 감축우선순위 점수 0.24, 추천 감축률 0% ~ 15% → 이유: 소비가 매우 일정하여 감축 여지가 낮습니다. (표준편차비: 0.14)
# • 메가커피 (카페): 탄소기여도 2.2%, 감축우선순위 점수 0.211, 추천 감축률 0% ~ 10% → 이유: 해당 브랜드의 소비 기록이 적어, 안전하게 0~10% 감축만 권장됩니다.
# • 런던베이글 (음식점): 탄소기여도 2.0%, 감축우선순위 점수 0.21, 추천 감축률 0% ~ 10% → 이유: 해당 브랜드의 소비 기록이 적어, 안전하게 0~10% 감축만 권장됩니다.
# • 롯데리아 (음식점): 탄소기여도 1.1%, 감축우선순위 점수 0.206, 추천 감축률 0% ~ 10% → 이유: 해당 브랜드의 소비 기록이 적어, 안전하게 0~10% 감축만 권장됩니다.
# • 오렌지주유소 (교통,수송): 탄소기여도 18.1%, 감축우선순위 점수 0.077, 추천 감축률 0% ~ 10% → 이유: 해당 브랜드의 소비 기록이 적어, 안전하게 0~10% 감축만 권장됩니다.
#
# 이 소비자에게 탄소 감축을 위해 어떤 실천 전략이 가장 효과적일까요?
# 항목별로 감축률을 선택할 수 있게 유도하고, 총 감축 효과가 얼마나 될지도 예측해주세요.
# 다음과 같은 형식에 맞춰 구체적으로 답변해 주세요. 반드시 아래 구조를 따르되, 내용은 소비자 특성에 맞게 맞춤화해 주세요:
#
#
#     1. 소비자 인삿말 및 분석 요약
#
#     2. [현재 소비 패턴 분석]
#     - 총지출 대비 탄소 배출량 특이점
#     - 어떤 업종/브랜드가 주요 기여자인지
#     - 탄소 감축 가능성이 있는 소비 패턴
#     - 추천 감축률이 낮은 이유 (ex: 소비 기록 적음)
#
#     3. [감축 전략 제안]
#     - 외식/문화 등 업종별 구체적 조언 포함
#     - 실천 가능한 행동 위주로 제안
#
#     4. [Top 5 항목별 감축률 가이드]
#     아래 형식을 반복해서 제시:
#     - 브랜드명 (업종)
#     - 현재 탄소 기여도 (kgCO₂)
#     - 추천 감축률 (예: 0% / 5% / 10% / 20% / 30%)
#     - 실천 전략 (bullet 2~3개)
#     - 감축률별 감축 예상량 (계산 기반)
#
#     5. [총 감축 효과 예측]
#     - 예시 시나리오 제시
#     - 각 항목 감축률 선택 + 총 감축량 계산
#     - 감축 후 총 배출량 제시
#
#     6. [마무리 코멘트]
#     - 긍정적인 격려
#     - 다음 단계 제안
#
#     **반드시 위 양식을 지켜 작성해주세요.**
#
# [Gemini 응답 - member 3]
# ## 1. 소비자 인삿말 및 분석 요약
#
# 안녕하세요, 소비자 3님! 한 달간의 소비 데이터를 분석한 결과, 총 2,301,630원을 지출하셨고, 이로 인해 10,661.9kgCO₂의 탄소가 배출된 것으로 나타났습니다. 탄소 감축에 대한 관심과 노력을 응원하며, 소비자 3님의 소비 패턴에 맞춰 효과적인 탄소 감축 전략을 제안해 드리고자 합니다.
#
# ## 2. [현재 소비 패턴 분석]
#
# *   **총지출 대비 탄소 배출량 특이점:** 총 지출액이 230만원대로 높은 편이며, 이에 따라 탄소 배출량도 10,661.9kgCO₂로 적지 않은 수준입니다. 특히, 교통/수송 부문의 탄소 기여도가 높은 점이 눈에 띕니다.
# *   **어떤 업종/브랜드가 주요 기여자인지:**
#     *   **교통/수송:** 오렌지주유소가 18.1%로 가장 높은 탄소 기여도를 보이며, 주요 감축 대상입니다.
#     *   **카페:** (주)에이비카페가 9.4%, 메가커피가 2.2%로 카페 업종의 기여도도 상당합니다.
#     *   **음식점:** 런던베이글(2.0%)과 롯데리아(1.1%) 등 외식 소비도 탄소 배출에 기여하고 있습니다.
# *   **탄소 감축 가능성이 있는 소비 패턴:**
#     *   **교통/수송:** 주유소 이용이 가장 큰 비중을 차지하므로, 이동 방식 변화를 통해 큰 폭의 감축이 가능합니다.
#     *   **카페/음식점:** 특정 브랜드에 대한 소비가 집중되어 있어, 해당 브랜드에서의 소비 습관 변화를 통해 감축을 시도할 수 있습니다.
# *   **추천 감축률이 낮은 이유 (ex: 소비 기록 적음):**
#     *   대부분의 추천 감축률이 0~10%로 낮게 제시된 이유는 해당 브랜드의 소비 기록이 충분하지 않아, 소비 패턴의 변동성을 정확히 파악하기 어렵기 때문입니다. 이는 갑작스러운 소비 변화가 아닌, 점진적이고 안정적인 감축을 유도하기 위함입니다. (주)에이비카페의 경우 소비가 매우 일정하여 감축 여지가 낮다고 분석되었습니다.
#
# ## 3. [감축 전략 제안]
#
# 소비자 3님의 소비 패턴을 고려할 때, 다음과 같은 실천 가능한 행동 위주로 감축 전략을 제안합니다.
#
# *   **교통/수송:**
#     *   **대중교통 이용 확대:** 가까운 거리는 도보나 자전거를 이용하고, 대중교통 이용을 생활화하여 주유소 이용 횟수를 줄여보세요.
#     *   **카풀/친환경 차량 고려:** 장거리 이동 시 카풀을 이용하거나, 장기적으로는 전기차 등 친환경 차량으로의 전환을 고려해볼 수 있습니다.
# *   **외식/카페:**
#     *   **텀블러 사용:** 카페 이용 시 개인 텀블러를 사용하여 일회용 컵 사용을 줄여보세요.
#     *   **메뉴 선택:** 육류 위주의 메뉴보다는 채식 위주의 메뉴를 선택하는 것도 탄소 감축에 도움이 됩니다.
#     *   **포장/배달 최소화:** 불필요한 포장재 사용을 줄이기 위해 매장 식사를 선호하고, 배달보다는 직접 방문하여 음식을 픽업하는 것을 고려해 보세요.
# *   **전반적인 소비 습관:**
#     *   **불필요한 소비 줄이기:** 구매 전 한 번 더 생각하고, 정말 필요한 물건인지, 대체할 수 있는 것은 없는지 고민하는 습관을 들여보세요.
#     *   **친환경 제품 선택:** 제품 구매 시 친환경 인증 마크가 있거나, 재활용 가능한 제품을 우선적으로 선택하는 것도 좋은 방법입니다.
#
# ## 4. [Top 5 항목별 감축률 가이드]
#
# **오렌지주유소 (교통,수송)**
# *   현재 탄소 기여도: 18.1% (약 1930kgCO₂)
# *   추천 감축률: 0% / 5% / 10%
# *   실천 전략:
#     *   주 1회 대중교통 이용 또는 도보/자전거 출퇴근 시도
#     *   불필요한 차량 운행 자제 (예: 가까운 마트 방문 시 도보 이용)
#     *   카풀 앱 활용 또는 지인과 함께 이동
# *   감축률별 감축 예상량:
#     *   5% 감축 시: 약 96.5kgCO₂ 감축
#     *   10% 감축 시: 약 193kgCO₂ 감축
#
# **(주)에이비카페 (카페)**
# *   현재 탄소 기여도: 9.4% (약 1002kgCO₂)
# *   추천 감축률: 0% / 5% / 10%
# *   실천 전략:
#     *   주 1~2회 텀블러 사용 습관화
#     *   커피 대신 물이나 차 마시는 날 정하기
#     *   카페 방문 횟수를 주 1회 줄이기
# *   감축률별 감축 예상량:
#     *   5% 감축 시: 약 50.1kgCO₂ 감축
#     *   10% 감축 시: 약 100.2kgCO₂ 감축
#
# **메가커피 (카페)**
# *   현재 탄소 기여도: 2.2% (약 234.6kgCO₂)
# *   추천 감축률: 0% / 5% / 10%
# *   실천 전략:
#     *   메가커피 방문 시 텀블러 사용
#     *   메가커피 대신 집에서 커피 내려 마시기
#     *   메가커피 방문 횟수를 월 1회 줄이기
# *   감축률별 감축 예상량:
#     *   5% 감축 시: 약 11.7kgCO₂ 감축
#     *   10% 감축 시: 약 23.5kgCO₂ 감축
#
# **런던베이글 (음식점)**
# *   현재 탄소 기여도: 2.0% (약 213.2kgCO₂)
# *   추천 감축률: 0% / 5% / 10%
# *   실천 전략:
#     *   런던베이글 방문 시 포장 대신 매장 식사 고려
#     *   베이글 대신 집에서 간단한 아침 식사 준비
#     *   런던베이글 방문 횟수를 월 1회 줄이기
# *   감축률별 감축 예상량:
#     *   5% 감축 시: 약 10.7kgCO₂ 감축
#     *   10% 감축 시: 약 21.3kgCO₂ 감축
#
# **롯데리아 (음식점)**
# *   현재 탄소 기여도: 1.1% (약 117.3kgCO₂)
# *   추천 감축률: 0% / 5% / 10%
# *   실천 전략:
#     *   롯데리아 방문 시 일회용품 사용 최소화 (매장 식사, 개인 컵 사용 등)
#     *   패스트푸드 대신 건강한 식단 선택
#     *   롯데리아 방문 횟수를 월 1회 줄이기
# *   감축률별 감축 예상량:
#     *   5% 감축 시: 약 5.9kgCO₂ 감축
#     *   10% 감축 시: 약 11.7kgCO₂ 감축
#
# ## 5. [총 감축 효과 예측]
#
# 소비자 3님께서 위에서 제안된 감축률을 선택했을 때의 총 감축 효과를 예측해 보겠습니다.
#
# **예시 시나리오:**
#
# *   **오렌지주유소:** 10% 감축
# *   **(주)에이비카페:** 5% 감축
# *   **메가커피:** 10% 감축
# *   **런던베이글:** 5% 감축
# *   **롯데리아:** 10% 감축
#
# **각 항목 감축률 선택 + 총 감축량 계산:**
#
# *   오렌지주유소: 1930kgCO₂ * 0.10 = 193kgCO₂ 감축
# *   (주)에이비카페: 1002kgCO₂ * 0.05 = 50.1kgCO₂ 감축
# *   메가커피: 234.6kgCO₂ * 0.10 = 23.5kgCO₂ 감축
# *   런던베이글: 213.2kgCO₂ * 0.05 = 10.7kgCO₂ 감축
# *   롯데리아: 117.3kgCO₂ * 0.10 = 11.7kgCO₂ 감축
#
# **총 감축량:** 193 + 50.1 + 23.5 + 10.7 + 11.7 = **289kgCO₂**
#
# **감축 후 총 배출량:** 10661.9kgCO₂ - 289kgCO₂ = **10372.9kgCO₂**
#
# 이 시나리오대로 실천하시면 한 달에 약 289kgCO₂의 탄소를 감축하여, 총 탄소 배출량을 10372.9kgCO₂로 줄일 수 있습니다. 이는 약 2.7%의 탄소 감축 효과를 가져옵니다.
#
# ## 6. [마무리 코멘트]
#
# 소비자 3님, 탄소 감축을 위한 작은 실천들이 모여 큰 변화를 만들 수 있습니다. 위에서 제안된 전략들은 시작에 불과하며, 소비자 3님의 라이프스타일에 맞춰 유연하게 적용하고 새로운 아이디어를 추가해 나가는 것이 중요합니다.
#
# 다음 달에는 감축 목표를 달성하셨는지, 어떤 변화가 있었는지 다시 한번 데이터를 분석하여 더 효과적인 맞춤형 전략을 제안해 드리겠습니다. 지속적인 관심과 노력을 통해 더욱 친환경적인 소비 생활을 만들어나가시길 응원합니다!
# --------------------------------------------------
#
# [Gemini 프롬프트 - member 4]
# 소비자 4의 한 달 소비 요약:
# - 총 지출: 5840813원, 총 탄소 배출: 24700.0kgCO₂
# - 탄소 감축 우선순위 Top 5 항목:
# • 톡스앤필의원 (의료,건강): 탄소기여도 79.4%, 감축우선순위 점수 0.275, 추천 감축률 0% ~ 15% → 이유: 소비가 매우 일정하여 감축 여지가 낮습니다. (표준편차비: 0.07)
# • (주)에이비카페 (카페): 탄소기여도 1.6%, 감축우선순위 점수 0.209, 추천 감축률 10% ~ 40% → 이유: 소비 변동성이 중간 수준이며, 10~40% 범위 감축이 가능합니다. (표준편차비: 0.55)
# • 쿰베오 (카페): 탄소기여도 0.9%, 감축우선순위 점수 0.206, 추천 감축률 0% ~ 10% → 이유: 해당 브랜드의 소비 기록이 적어, 안전하게 0~10% 감축만 권장됩니다.
# • 맥도날드 (음식점): 탄소기여도 0.6%, 감축우선순위 점수 0.204, 추천 감축률 0% ~ 10% → 이유: 해당 브랜드의 소비 기록이 적어, 안전하게 0~10% 감축만 권장됩니다.
# • 이마트 (대형마트): 탄소기여도 6.4%, 감축우선순위 점수 0.027, 추천 감축률 10% ~ 40% → 이유: 소비 변동성이 중간 수준이며, 10~40% 범위 감축이 가능합니다. (표준편차비: 0.59)
#
# 이 소비자에게 탄소 감축을 위해 어떤 실천 전략이 가장 효과적일까요?
# 항목별로 감축률을 선택할 수 있게 유도하고, 총 감축 효과가 얼마나 될지도 예측해주세요.
# 다음과 같은 형식에 맞춰 구체적으로 답변해 주세요. 반드시 아래 구조를 따르되, 내용은 소비자 특성에 맞게 맞춤화해 주세요:
#
#
#     1. 소비자 인삿말 및 분석 요약
#
#     2. [현재 소비 패턴 분석]
#     - 총지출 대비 탄소 배출량 특이점
#     - 어떤 업종/브랜드가 주요 기여자인지
#     - 탄소 감축 가능성이 있는 소비 패턴
#     - 추천 감축률이 낮은 이유 (ex: 소비 기록 적음)
#
#     3. [감축 전략 제안]
#     - 외식/문화 등 업종별 구체적 조언 포함
#     - 실천 가능한 행동 위주로 제안
#
#     4. [Top 5 항목별 감축률 가이드]
#     아래 형식을 반복해서 제시:
#     - 브랜드명 (업종)
#     - 현재 탄소 기여도 (kgCO₂)
#     - 추천 감축률 (예: 0% / 5% / 10% / 20% / 30%)
#     - 실천 전략 (bullet 2~3개)
#     - 감축률별 감축 예상량 (계산 기반)
#
#     5. [총 감축 효과 예측]
#     - 예시 시나리오 제시
#     - 각 항목 감축률 선택 + 총 감축량 계산
#     - 감축 후 총 배출량 제시
#
#     6. [마무리 코멘트]
#     - 긍정적인 격려
#     - 다음 단계 제안
#
#     **반드시 위 양식을 지켜 작성해주세요.**
#
# [Gemini 응답 - member 4]
# ## 1. 소비자 인삿말 및 분석 요약
#
# 안녕하세요, 소비자 4님! 한 달간의 소비 데이터를 바탕으로 탄소 배출 현황을 분석해 드립니다. 총 지출 5,840,813원에 총 탄소 배출량은 24,700.0kgCO₂로 나타났습니다. 특히 '톡스앤필의원'이 탄소 배출에 가장 큰 영향을 미치고 있지만, 소비가 매우 일정하여 감축 여지가 낮은 것으로 분석됩니다. 하지만 '이마트'와 '카페' 업종에서 탄소 감축의 기회가 보입니다.
#
# ## 2. [현재 소비 패턴 분석]
#
# *   **총지출 대비 탄소 배출량 특이점**: 총 지출액이 높은 편임에도 불구하고, 특정 의료 서비스(톡스앤필의원)가 탄소 배출의 대부분을 차지하고 있어 일반적인 소비 패턴과는 다른 특이점을 보입니다. 이는 의료 서비스의 탄소 배출 계수가 높거나, 해당 서비스 이용 빈도가 매우 높기 때문으로 추정됩니다.
# *   **어떤 업종/브랜드가 주요 기여자인지**:
#     *   **톡스앤필의원 (의료, 건강)**: 전체 탄소 배출의 79.4%를 차지하는 압도적인 1위 기여자입니다.
#     *   **이마트 (대형마트)**: 6.4%로 두 번째로 높은 기여도를 보입니다.
#     *   **카페 (에이비카페, 쿰베오)**: 각각 1.6%, 0.9%로 상대적으로 낮은 기여도이지만, 일상생활에서 쉽게 감축할 수 있는 항목입니다.
#     *   **맥도날드 (음식점)**: 0.6%로 낮은 기여도를 보입니다.
# *   **탄소 감축 가능성이 있는 소비 패턴**:
#     *   **이마트 (대형마트)**: 소비 변동성이 중간 수준(표준편차비 0.59)으로, 10%~40% 감축이 가능하다고 분석됩니다. 이는 장보기 습관 개선을 통해 충분히 감축할 수 있는 여지가 있음을 의미합니다.
#     *   **카페 (에이비카페)**: 소비 변동성이 중간 수준(표준편차비 0.55)으로, 10%~40% 감축이 가능합니다. 일상적인 카페 이용 습관을 조금만 바꿔도 효과를 볼 수 있습니다.
# *   **추천 감축률이 낮은 이유 (ex: 소비 기록 적음)**:
#     *   **톡스앤필의원**: 소비가 매우 일정하여(표준편차비 0.07) 감축 여지가 낮다고 판단됩니다. 이는 필수적인 의료 서비스일 가능성이 높기 때문입니다.
#     *   **쿰베오, 맥도날드**: 해당 브랜드의 소비 기록이 적어, 데이터 부족으로 인해 안전하게 0%~10%의 낮은 감축률만 권장되었습니다.
#
# ## 3. [감축 전략 제안]
#
# 소비자 4님께서는 의료 서비스 외의 일상 소비에서 탄소 감축의 기회를 찾을 수 있습니다. 특히 대형마트와 카페 이용 습관을 개선하는 것이 효과적입니다.
#
# *   **외식/문화 등 업종별 구체적 조언 포함**:
#     *   **대형마트 (이마트)**:
#         *   **장보기 계획 세우기**: 불필요한 충동구매를 줄이고, 필요한 물품만 구매하여 음식물 쓰레기를 줄입니다.
#         *   **친환경 제품 선택**: 친환경 인증을 받은 제품이나 로컬푸드를 구매하여 운송 과정에서의 탄소 배출을 줄입니다.
#         *   **다회용 장바구니 사용**: 비닐봉투 사용을 줄여 플라스틱 폐기물 발생을 억제합니다.
#     *   **카페 (에이비카페, 쿰베오)**:
#         *   **개인 컵/텀블러 사용**: 일회용 컵 사용을 줄여 플라스틱 및 종이 폐기물을 줄입니다. 많은 카페에서 텀블러 할인 혜택을 제공하기도 합니다.
#         *   **음료 사이즈 조절**: 불필요하게 큰 사이즈의 음료를 주문하지 않고, 적정량을 선택하여 잔반을 줄입니다.
#         *   **식물성 우유 옵션 선택**: 우유 대신 두유, 오트밀크 등 식물성 우유를 선택하면 유제품 생산 과정에서 발생하는 탄소 배출을 줄일 수 있습니다.
#     *   **음식점 (맥도날드)**:
#         *   **포장 시 다회용기 사용 고려**: 일부 음식점에서는 다회용기 사용을 허용하는 곳도 있으니 확인해 보세요.
#         *   **음식물 남기지 않기**: 주문 시 적정량을 주문하고, 남기지 않도록 노력합니다.
#
# *   **실천 가능한 행동 위주로 제안**:
#     *   매주 장보기 전에 냉장고를 확인하고 필요한 품목 리스트를 작성하는 습관을 들여보세요.
#     *   외출 시 항상 텀블러를 챙기는 것을 습관화해 보세요.
#     *   배달 음식 주문 시 불필요한 일회용품(수저, 포크 등)은 받지 않겠다고 요청해 보세요.
#
# ## 4. [Top 5 항목별 감축률 가이드]
#
# **현재 탄소 배출량은 총 24,700.0kgCO₂입니다.**
#
# *   **톡스앤필의원 (의료,건강)**
#     *   현재 탄소 기여도: 19600.0kgCO₂ (79.4%)
#     *   추천 감축률: 0% / 5%
#     *   실천 전략:
#         *   해당 서비스는 필수적인 의료 서비스일 가능성이 높으므로, 무리한 감축보다는 현재 수준을 유지하는 것을 권장합니다.
#         *   만약 대체 가능한 친환경적인 의료 서비스가 있다면 고려해 볼 수 있습니다.
#     *   감축률별 감축 예상량:
#         *   0% 감축: 0kgCO₂
#         *   5% 감축: 980kgCO₂
#
# *   **(주)에이비카페 (카페)**
#     *   현재 탄소 기여도: 395.2kgCO₂ (1.6%)
#     *   추천 감축률: 10% / 20% / 30% / 40%
#     *   실천 전략:
#         *   개인 컵/텀블러를 사용하여 일회용 컵 사용을 줄입니다.
#         *   주 1~2회 정도는 카페 방문 대신 집에서 직접 커피를 내려 마시는 것을 고려합니다.
#         *   식물성 우유 옵션이 있다면 선택하여 탄소 발자국을 줄입니다.
#     *   감축률별 감축 예상량:
#         *   10% 감축: 39.52kgCO₂
#         *   20% 감축: 79.04kgCO₂
#         *   30% 감축: 118.56kgCO₂
#         *   40% 감축: 158.08kgCO₂
#
# *   **쿰베오 (카페)**
#     *   현재 탄소 기여도: 222.3kgCO₂ (0.9%)
#     *   추천 감축률: 0% / 5% / 10%
#     *   실천 전략:
#         *   해당 브랜드 방문 시에도 개인 컵/텀블러 사용을 습관화합니다.
#         *   방문 빈도를 주 1회 정도 줄이는 것을 고려해 봅니다.
#     *   감축률별 감축 예상량:
#         *   0% 감축: 0kgCO₂
#         *   5% 감축: 11.115kgCO₂
#         *   10% 감축: 22.23kgCO₂
#
# *   **맥도날드 (음식점)**
#     *   현재 탄소 기여도: 148.2kgCO₂ (0.6%)
#     *   추천 감축률: 0% / 5% / 10%
#     *   실천 전략:
#         *   방문 시 불필요한 일회용품(빨대, 플라스틱 수저 등)은 받지 않겠다고 요청합니다.
#         *   가끔은 패스트푸드 대신 채식 위주의 식사를 선택하여 탄소 배출을 줄입니다.
#     *   감축률별 감축 예상량:
#         *   0% 감축: 0kgCO₂
#         *   5% 감축: 7.41kgCO₂
#         *   10% 감축: 14.82kgCO₂
#
# *   **이마트 (대형마트)**
#     *   현재 탄소 기여도: 1580.8kgCO₂ (6.4%)
#     *   추천 감축률: 10% / 20% / 30% / 40%
#     *   실천 전략:
#         *   장보기 전 필요한 물품 목록을 작성하고, 충동구매를 자제합니다.
#         *   다회용 장바구니를 항상 지참하여 비닐봉투 사용을 줄입니다.
#         *   과대 포장된 제품보다는 친환경 포장 제품을 선택합니다.
#         *   로컬푸드나 제철 식품을 구매하여 운송 거리를 줄입니다.
#     *   감축률별 감축 예상량:
#         *   10% 감축: 158.08kgCO₂
#         *   20% 감축: 316.16kgCO₂
#         *   30% 감축: 474.24kgCO₂
#         *   40% 감축: 632.32kgCO₂
#
# ## 5. [총 감축 효과 예측]
#
# 소비자 4님의 탄소 감축 목표를 달성하기 위한 시나리오를 제안합니다.
#
# **예시 시나리오: 현실적인 감축 목표 설정**
#
# *   **톡스앤필의원**: 0% 감축 (필수 의료 서비스로 간주)
# *   **(주)에이비카페**: 20% 감축 (텀블러 사용 및 주 1회 자제)
# *   **쿰베오**: 10% 감축 (텀블러 사용 및 방문 빈도 소폭 조절)
# *   **맥도날드**: 10% 감축 (일회용품 자제 및 가끔 채식 선택)
# *   **이마트**: 20% 감축 (계획적인 장보기 및 다회용품 사용)
#
# **각 항목 감축률 선택 및 총 감축량 계산:**
#
# *   톡스앤필의원: 19600.0kgCO₂ * 0% = 0kgCO₂
# *   (주)에이비카페: 395.2kgCO₂ * 20% = 79.04kgCO₂
# *   쿰베오: 222.3kgCO₂ * 10% = 22.23kgCO₂
# *   맥도날드: 148.2kgCO₂ * 10% = 14.82kgCO₂
# *   이마트: 1580.8kgCO₂ * 20% = 316.16kgCO₂
#
# **총 예상 감축량:** 0 + 79.04 + 22.23 + 14.82 + 316.16 = **432.25kgCO₂**
#
# **감축 후 총 배출량 제시:**
#
# 현재 총 탄소 배출량 24,700.0kgCO₂ - 예상 감축량 432.25kgCO₂ = **24,267.75kgCO₂**
#
# 이 시나리오대로 실천하시면 한 달에 약 432.25kgCO₂의 탄소를 줄일 수 있으며, 이는 총 탄소 배출량을 24,267.75kgCO₂로 낮추는 효과를 가져옵니다.
#
# ## 6. [마무리 코멘트]
#
# 소비자 4님, 탄소 감축을 위한 첫걸음을 내딛으신 것을 진심으로 응원합니다! '톡스앤필의원'의 높은 탄소 기여도는 감축이 어렵지만, 일상생활에서 자주 이용하시는 '이마트'와 '카페'에서 작은 변화를 통해 의미 있는 탄소 감축 효과를 볼 수 있습니다.
#
# 오늘 제안 드린 실천 전략들을 하나씩 시도해 보시면서, 자신에게 맞는 지속 가능한 방법을 찾아보세요. 작은 실천들이 모여 큰 변화를 만들 수 있습니다. 다음 달에는 더욱 줄어든 탄소 배출량을 확인할 수 있기를 기대합니다! 궁금한 점이 있다면 언제든지 다시 문의해주세요.
# --------------------------------------------------
#
# [Gemini 프롬프트 - member 5]
# 소비자 5의 한 달 소비 요약:
# - 총 지출: 5179317원, 총 탄소 배출: 77077.8kgCO₂
# - 탄소 감축 우선순위 Top 5 항목:
# • 오렌지주유소 (교통,수송): 탄소기여도 82.6%, 감축우선순위 점수 0.299, 추천 감축률 10% ~ 40% → 이유: 소비 변동성이 중간 수준이며, 10~40% 범위 감축이 가능합니다. (표준편차비: 0.41)
# • (주)에이비카페 (카페): 탄소기여도 0.7%, 감축우선순위 점수 0.205, 추천 감축률 10% ~ 40% → 이유: 소비 변동성이 중간 수준이며, 10~40% 범위 감축이 가능합니다. (표준편차비: 0.56)
# • 메가커피 (카페): 탄소기여도 0.1%, 감축우선순위 점수 0.203, 추천 감축률 0% ~ 10% → 이유: 해당 브랜드의 소비 기록이 적어, 안전하게 0~10% 감축만 권장됩니다.
# • 쿰베오 (카페): 탄소기여도 0.1%, 감축우선순위 점수 0.203, 추천 감축률 0% ~ 10% → 이유: 해당 브랜드의 소비 기록이 적어, 안전하게 0~10% 감축만 권장됩니다.
# • 롯데리아 (음식점): 탄소기여도 0.0%, 감축우선순위 점수 0.202, 추천 감축률 0% ~ 10% → 이유: 해당 브랜드의 소비 기록이 적어, 안전하게 0~10% 감축만 권장됩니다.
#
# 이 소비자에게 탄소 감축을 위해 어떤 실천 전략이 가장 효과적일까요?
# 항목별로 감축률을 선택할 수 있게 유도하고, 총 감축 효과가 얼마나 될지도 예측해주세요.
# 다음과 같은 형식에 맞춰 구체적으로 답변해 주세요. 반드시 아래 구조를 따르되, 내용은 소비자 특성에 맞게 맞춤화해 주세요:
#
#
#     1. 소비자 인삿말 및 분석 요약
#
#     2. [현재 소비 패턴 분석]
#     - 총지출 대비 탄소 배출량 특이점
#     - 어떤 업종/브랜드가 주요 기여자인지
#     - 탄소 감축 가능성이 있는 소비 패턴
#     - 추천 감축률이 낮은 이유 (ex: 소비 기록 적음)
#
#     3. [감축 전략 제안]
#     - 외식/문화 등 업종별 구체적 조언 포함
#     - 실천 가능한 행동 위주로 제안
#
#     4. [Top 5 항목별 감축률 가이드]
#     아래 형식을 반복해서 제시:
#     - 브랜드명 (업종)
#     - 현재 탄소 기여도 (kgCO₂)
#     - 추천 감축률 (예: 0% / 5% / 10% / 20% / 30%)
#     - 실천 전략 (bullet 2~3개)
#     - 감축률별 감축 예상량 (계산 기반)
#
#     5. [총 감축 효과 예측]
#     - 예시 시나리오 제시
#     - 각 항목 감축률 선택 + 총 감축량 계산
#     - 감축 후 총 배출량 제시
#
#     6. [마무리 코멘트]
#     - 긍정적인 격려
#     - 다음 단계 제안
#
#     **반드시 위 양식을 지켜 작성해주세요.**
#
# [Gemini 응답 - member 5]
# 안녕하세요, 소비자 5님! 한 달간의 소비 데이터를 분석한 결과, 총 5,179,317원을 지출하셨고, 이로 인해 77,077.8kgCO₂의 탄소가 배출된 것으로 나타났습니다. 특히 교통/수송 부문에서 탄소 배출량이 압도적으로 높은 비중을 차지하고 있어, 이 부분을 집중적으로 관리하시면 탄소 감축에 큰 효과를 보실 수 있을 것으로 예상됩니다.
#
# ### 2. 현재 소비 패턴 분석
#
# *   **총지출 대비 탄소 배출량 특이점**: 소비자 5님의 총 지출액은 5백만 원이 넘는 높은 수준이지만, 총 탄소 배출량 77,077.8kgCO₂는 지출 규모에 비해 매우 높은 편입니다. 이는 특정 소비 항목에서 탄소 집약도가 매우 높다는 것을 의미합니다.
# *   **어떤 업종/브랜드가 주요 기여자인지**: '오렌지주유소'가 전체 탄소 배출량의 82.6%를 차지하며 압도적인 1위입니다. 이는 교통/수송 부문이 소비자 5님의 탄소 발자국에서 가장 큰 비중을 차지하고 있음을 명확히 보여줍니다. 그 외 '㈜에이비카페' 등 카페 업종이 소폭 기여하고 있습니다.
# *   **탄소 감축 가능성이 있는 소비 패턴**: '오렌지주유소'의 경우 소비 변동성이 중간 수준으로 나타나 10%~40%의 감축이 가능하다고 분석되었습니다. 이는 주유 소비를 줄일 여지가 충분하다는 것을 의미합니다.
# *   **추천 감축률이 낮은 이유 (ex: 소비 기록 적음)**: '메가커피', '쿰베오', '롯데리아'와 같은 브랜드는 탄소 기여도가 매우 낮고, 소비 기록이 적어 안전하게 0~10%의 낮은 감축률이 권장되었습니다. 이는 해당 브랜드에서의 소비가 탄소 배출에 미치는 영향이 미미하며, 감축 목표를 설정하기 위한 충분한 데이터가 없기 때문입니다.
#
# ### 3. 감축 전략 제안
#
# 소비자 5님의 탄소 감축을 위한 가장 효과적인 전략은 '오렌지주유소'로 대표되는 교통/수송 부문의 탄소 배출량을 줄이는 것입니다. 그 외 카페, 음식점 등 일상 소비에서도 작은 노력을 더하면 더욱 큰 효과를 볼 수 있습니다.
#
# *   **교통/수송**: 자가용 이용을 줄이고 대중교통, 자전거 이용을 늘리거나, 가까운 거리는 걷는 습관을 들이는 것이 중요합니다. 불필요한 운전을 줄이고, 카풀이나 친환경 차량 이용을 고려해볼 수 있습니다.
# *   **외식/카페**: 카페 이용 시 텀블러를 사용하거나, 불필요한 일회용품 사용을 줄이는 것이 좋습니다. 외식 시에는 남기지 않고 먹을 만큼만 주문하고, 포장 시 다회용 용기를 사용하는 것도 좋은 방법입니다.
# *   **전반적인 소비 습관**: 불필요한 소비를 줄이고, 친환경 제품을 선택하는 등 지속 가능한 소비 습관을 형성하는 것이 장기적인 탄소 감축에 도움이 됩니다.
#
# ### 4. Top 5 항목별 감축률 가이드
#
# **오렌지주유소 (교통,수송)**
# *   현재 탄소 기여도: 82.6% (약 63,690kgCO₂)
# *   추천 감축률: 0% / 10% / 20% / 30% / 40%
# *   실천 전략:
#     *   주 1회 대중교통 이용 또는 자전거 출퇴근 시도
#     *   불필요한 단거리 운전 자제 및 도보 이동 습관화
#     *   카풀 참여 또는 친환경 차량 이용 고려
# *   감축률별 감축 예상량:
#     *   0% 선택 시: 0kgCO₂ 감축
#     *   10% 선택 시: 약 6,369kgCO₂ 감축
#     *   20% 선택 시: 약 12,738kgCO₂ 감축
#     *   30% 선택 시: 약 19,107kgCO₂ 감축
#     *   40% 선택 시: 약 25,476kgCO₂ 감축
#
# **㈜에이비카페 (카페)**
# *   현재 탄소 기여도: 0.7% (약 539.5kgCO₂)
# *   추천 감축률: 0% / 10% / 20% / 30% / 40%
# *   실천 전략:
#     *   카페 방문 시 개인 텀블러 사용 습관화
#     *   일주일에 1~2회 카페 방문 대신 집에서 커피 마시기
#     *   불필요한 일회용품(빨대, 컵홀더 등) 사용 자제
# *   감축률별 감축 예상량:
#     *   0% 선택 시: 0kgCO₂ 감축
#     *   10% 선택 시: 약 53.95kgCO₂ 감축
#     *   20% 선택 시: 약 107.9kgCO₂ 감축
#     *   30% 선택 시: 약 161.85kgCO₂ 감축
#     *   40% 선택 시: 약 215.8kgCO₂ 감축
#
# **메가커피 (카페)**
# *   현재 탄소 기여도: 0.1% (약 77.1kgCO₂)
# *   추천 감축률: 0% / 5% / 10%
# *   실천 전략:
#     *   메가커피 방문 시 텀블러 사용
#     *   주 1회 메가커피 방문 대신 다른 카페 이용 또는 자제
#     *   포장 시 불필요한 비닐봉투 거절
# *   감축률별 감축 예상량:
#     *   0% 선택 시: 0kgCO₂ 감축
#     *   5% 선택 시: 약 3.85kgCO₂ 감축
#     *   10% 선택 시: 약 7.71kgCO₂ 감축
#
# **쿰베오 (카페)**
# *   현재 탄소 기여도: 0.1% (약 77.1kgCO₂)
# *   추천 감축률: 0% / 5% / 10%
# *   실천 전략:
#     *   쿰베오 방문 시 텀블러 사용
#     *   주 1회 쿰베오 방문 대신 다른 카페 이용 또는 자제
#     *   디저트 포장 시 다회용 용기 사용 고려
# *   감축률별 감축 예상량:
#     *   0% 선택 시: 0kgCO₂ 감축
#     *   5% 선택 시: 약 3.85kgCO₂ 감축
#     *   10% 선택 시: 약 7.71kgCO₂ 감축
#
# **롯데리아 (음식점)**
# *   현재 탄소 기여도: 0.0% (약 0kgCO₂ - 데이터상 0.0%로 표기되었으나, 실제로는 미미한 양이 있을 수 있음)
# *   추천 감축률: 0% / 5% / 10%
# *   실천 전략:
#     *   롯데리아 방문 시 남기지 않고 먹을 만큼만 주문
#     *   포장 시 불필요한 플라스틱 용기 대신 종이 포장 요청
#     *   일주일에 1회 롯데리아 방문 대신 집에서 식사하기
# *   감축률별 감축 예상량:
#     *   0% 선택 시: 0kgCO₂ 감축
#     *   5% 선택 시: 약 0kgCO₂ 감축 (실제 미미한 양 감축)
#     *   10% 선택 시: 약 0kgCO₂ 감축 (실제 미미한 양 감축)
#
# ### 5. 총 감축 효과 예측
#
# 소비자 5님께서 아래와 같이 감축률을 선택하신다고 가정해 보겠습니다.
#
# *   **오렌지주유소**: 30% 감축 선택 (약 19,107kgCO₂ 감축)
# *   **㈜에이비카페**: 20% 감축 선택 (약 107.9kgCO₂ 감축)
# *   **메가커피**: 10% 감축 선택 (약 7.71kgCO₂ 감축)
# *   **쿰베오**: 10% 감축 선택 (약 7.71kgCO₂ 감축)
# *   **롯데리아**: 5% 감축 선택 (약 0kgCO₂ 감축)
#
# **총 감축량 계산**: 19,107 + 107.9 + 7.71 + 7.71 + 0 = **약 19,230.32kgCO₂ 감축**
#
# **감축 후 총 배출량**: 77,077.8kgCO₂ - 19,230.32kgCO₂ = **약 57,847.48kgCO₂**
#
# 이 시나리오대로 실천하시면 한 달에 약 19톤 이상의 탄소를 감축하실 수 있으며, 이는 전체 탄소 배출량의 약 25%를 줄이는 효과를 가져옵니다. 특히 오렌지주유소에서의 감축이 전체 감축량의 대부분을 차지하는 것을 보실 수 있습니다.
#
# ### 6. 마무리 코멘트
#
# 소비자 5님, 한 달간의 소비 데이터를 통해 탄소 감축을 위한 의미 있는 첫걸음을 내디디셨습니다. 특히 교통/수송 부문에서의 노력이 가장 큰 변화를 가져올 수 있다는 점을 확인하셨을 것입니다. 작은 실천들이 모여 큰 변화를 만들 수 있으니, 오늘 제안 드린 전략들을 꾸준히 실천해 보시길 바랍니다.
#
# 다음 달에는 감축 목표 달성 여부를 함께 확인하고, 더 나아가 다른 소비 항목에서도 탄소 감축 기회를 찾아보도록 하겠습니다. 지속 가능한 미래를 위한 소비자 5님의 노력에 진심으로 감사드립니다!
# --------------------------------------------------
#
# [Gemini 프롬프트 - member 6]
# 소비자 6의 한 달 소비 요약:
# - 총 지출: 7088459원, 총 탄소 배출: 21744.0kgCO₂
# - 탄소 감축 우선순위 Top 5 항목:
# • 런던베이글 (음식점): 탄소기여도 5.1%, 감축우선순위 점수 0.223, 추천 감축률 10% ~ 40% → 이유: 소비 변동성이 중간 수준이며, 10~40% 범위 감축이 가능합니다. (표준편차비: 0.43)
# • (주)에이비카페 (카페): 탄소기여도 3.7%, 감축우선순위 점수 0.217, 추천 감축률 0% ~ 15% → 이유: 소비가 매우 일정하여 감축 여지가 낮습니다. (표준편차비: 0.15)
# • 쿰베오 (카페): 탄소기여도 2.4%, 감축우선순위 점수 0.212, 추천 감축률 0% ~ 15% → 이유: 소비가 매우 일정하여 감축 여지가 낮습니다. (표준편차비: 0.35)
# • 더벤티 (카페): 탄소기여도 2.2%, 감축우선순위 점수 0.211, 추천 감축률 20% ~ 80% → 이유: 소비 변동성이 매우 크기 때문에, 최대 80%까지도 감축 가능합니다. (표준편차비: 0.76)
# • 맥도날드 (음식점): 탄소기여도 2.1%, 감축우선순위 점수 0.211, 추천 감축률 0% ~ 15% → 이유: 소비가 매우 일정하여 감축 여지가 낮습니다. (표준편차비: nan)
#
# 이 소비자에게 탄소 감축을 위해 어떤 실천 전략이 가장 효과적일까요?
# 항목별로 감축률을 선택할 수 있게 유도하고, 총 감축 효과가 얼마나 될지도 예측해주세요.
# 다음과 같은 형식에 맞춰 구체적으로 답변해 주세요. 반드시 아래 구조를 따르되, 내용은 소비자 특성에 맞게 맞춤화해 주세요:
#
#
#     1. 소비자 인삿말 및 분석 요약
#
#     2. [현재 소비 패턴 분석]
#     - 총지출 대비 탄소 배출량 특이점
#     - 어떤 업종/브랜드가 주요 기여자인지
#     - 탄소 감축 가능성이 있는 소비 패턴
#     - 추천 감축률이 낮은 이유 (ex: 소비 기록 적음)
#
#     3. [감축 전략 제안]
#     - 외식/문화 등 업종별 구체적 조언 포함
#     - 실천 가능한 행동 위주로 제안
#
#     4. [Top 5 항목별 감축률 가이드]
#     아래 형식을 반복해서 제시:
#     - 브랜드명 (업종)
#     - 현재 탄소 기여도 (kgCO₂)
#     - 추천 감축률 (예: 0% / 5% / 10% / 20% / 30%)
#     - 실천 전략 (bullet 2~3개)
#     - 감축률별 감축 예상량 (계산 기반)
#
#     5. [총 감축 효과 예측]
#     - 예시 시나리오 제시
#     - 각 항목 감축률 선택 + 총 감축량 계산
#     - 감축 후 총 배출량 제시
#
#     6. [마무리 코멘트]
#     - 긍정적인 격려
#     - 다음 단계 제안
#
#     **반드시 위 양식을 지켜 작성해주세요.**
#
# [Gemini 응답 - member 6]
# ## 1. 소비자 인삿말 및 분석 요약
#
# 안녕하세요, 소비자 6님! 한 달간의 소비 데이터를 통해 탄소 배출 현황을 분석해 보았습니다. 총 지출 7,088,459원에 21,744.0kgCO₂의 탄소를 배출하셨습니다. 이는 일반적인 소비 활동에서 발생하는 탄소량보다 높은 수준으로, 특히 외식 및 카페 이용이 탄소 배출에 큰 영향을 미치고 있는 것으로 보입니다.
#
# 이번 분석을 통해 소비자 6님의 소비 패턴을 파악하고, 효과적인 탄소 감축을 위한 맞춤형 전략을 제안해 드리고자 합니다. 함께 지속 가능한 소비 습관을 만들어나가요!
#
# ## 2. [현재 소비 패턴 분석]
#
# *   **총지출 대비 탄소 배출량 특이점:** 소비자 6님의 총 지출액이 높은 편이며, 이에 비례하여 탄소 배출량도 상당한 수준입니다. 이는 소비 활동 전반에서 탄소 배출량이 높은 품목이나 서비스 이용이 많다는 것을 시사합니다.
#
# *   **어떤 업종/브랜드가 주요 기여자인지:**
#     *   **음식점:** '런던베이글'과 '맥도날드'가 탄소 배출 상위 5개 항목에 포함되어 외식 활동이 주요 탄소 배출원임을 알 수 있습니다. 특히 런던베이글은 탄소 기여도가 5.1%로 가장 높습니다.
#     *   **카페:** '(주)에이비카페', '쿰베오', '더벤티' 등 3개의 카페 브랜드가 상위 5개 항목에 포함되어 있습니다. 이는 카페 이용 빈도가 높고, 이로 인한 탄소 배출량도 상당하다는 것을 보여줍니다.
#
# *   **탄소 감축 가능성이 있는 소비 패턴:**
#     *   **런던베이글 (음식점):** 소비 변동성이 중간 수준(표준편차비: 0.43)으로, 10%~40%의 감축 여지가 있습니다. 특정 메뉴를 줄이거나 방문 횟수를 조절하는 방식으로 감축이 가능할 것으로 보입니다.
#     *   **더벤티 (카페):** 소비 변동성이 매우 크기(표준편차비: 0.76) 때문에, 최대 80%까지도 감축이 가능하다고 분석되었습니다. 이는 특정 시기에 집중적으로 소비하거나, 대체 가능한 다른 카페를 이용하는 등의 패턴이 있을 수 있음을 의미합니다.
#
# *   **추천 감축률이 낮은 이유 (ex: 소비 기록 적음):**
#     *   **(주)에이비카페, 쿰베오, 맥도날드:** 이 세 브랜드는 소비가 매우 일정하여 감축 여지가 낮다고 분석되었습니다. 특히 맥도날드의 경우 표준편차비가 'nan'으로, 이는 해당 기간 동안 소비 기록이 매우 적거나, 단일 거래로 인해 변동성을 측정하기 어려웠을 가능성을 시사합니다. 소비가 일정하다는 것은 해당 브랜드에 대한 선호도가 높거나, 습관적인 소비가 이루어지고 있음을 의미할 수 있습니다.
#
# ## 3. [감축 전략 제안]
#
# 소비자 6님의 탄소 감축을 위해 다음과 같은 실천 전략을 제안합니다.
#
# *   **외식/카페 소비 조절:**
#     *   **외식 횟수 줄이기:** 런던베이글과 맥도날드 등 외식 브랜드의 탄소 기여도가 높으므로, 외식 횟수를 주 1회 줄이거나, 집에서 직접 요리하는 횟수를 늘려보세요.
#     *   **카페 이용 습관 개선:** 더벤티와 같이 소비 변동성이 큰 카페는 방문 횟수를 줄이거나, 텀블러를 사용하여 일회용품 사용을 줄이는 등 친환경적인 소비를 실천해 보세요. 에이비카페나 쿰베오처럼 소비가 일정한 카페는 방문 횟수를 급격히 줄이기 어렵다면, 텀블러 사용을 생활화하여 탄소 배출량을 줄이는 데 집중하는 것이 좋습니다.
#     *   **메뉴 선택의 변화:** 고기 위주의 메뉴보다는 채식 위주의 메뉴를 선택하거나, 제철 식재료를 활용한 메뉴를 선택하는 것도 탄소 감축에 도움이 됩니다.
#
# *   **친환경 소비 습관 형성:**
#     *   **텀블러 사용 생활화:** 카페 이용 시 텀블러를 사용하여 일회용 컵 사용을 줄이면 상당한 탄소 감축 효과를 볼 수 있습니다.
#     *   **다회용기 사용:** 포장 주문 시 다회용기를 사용하는 습관을 들여 플라스틱 쓰레기를 줄여보세요.
#     *   **대중교통 이용 및 걷기:** 가까운 거리는 대중교통을 이용하거나 걷는 습관을 들여 차량 이용으로 인한 탄소 배출을 줄일 수 있습니다.
#
# ## 4. [Top 5 항목별 감축률 가이드]
#
# 각 항목별로 추천 감축률을 제시하고, 실천 전략과 예상 감축량을 안내해 드립니다.
#
# *   **런던베이글 (음식점)**
#     *   현재 탄소 기여도: 1108.9kgCO₂ (총 21744.0kgCO₂의 5.1%)
#     *   추천 감축률: 0% / 10% / 20% / 30% / 40%
#     *   실천 전략:
#         *   한 달에 1~2회 방문 횟수를 줄여보세요.
#         *   포장 시 다회용기를 사용하거나, 불필요한 일회용품 사용을 자제하세요.
#         *   고기류 메뉴 대신 채식 위주의 메뉴를 선택하는 것을 고려해 보세요.
#     *   감축률별 감축 예상량:
#         *   0% 감축: 0kgCO₂
#         *   10% 감축: 110.9kgCO₂
#         *   20% 감축: 221.8kgCO₂
#         *   30% 감축: 332.7kgCO₂
#         *   40% 감축: 443.6kgCO₂
#
# *   **(주)에이비카페 (카페)**
#     *   현재 탄소 기여도: 804.5kgCO₂ (총 21744.0kgCO₂의 3.7%)
#     *   추천 감축률: 0% / 5% / 10% / 15%
#     *   실천 전략:
#         *   방문 시 항상 텀블러를 사용하여 일회용 컵 사용을 줄이세요.
#         *   불필요한 추가 주문(예: 시럽, 휘핑크림)을 줄여보세요.
#         *   가끔은 집에서 직접 커피를 내려 마시는 것을 고려해 보세요.
#     *   감축률별 감축 예상량:
#         *   0% 감축: 0kgCO₂
#         *   5% 감축: 40.2kgCO₂
#         *   10% 감축: 80.5kgCO₂
#         *   15% 감축: 120.7kgCO₂
#
# *   **쿰베오 (카페)**
#     *   현재 탄소 기여도: 521.9kgCO₂ (총 21744.0kgCO₂의 2.4%)
#     *   추천 감축률: 0% / 5% / 10% / 15%
#     *   실천 전략:
#         *   방문 시 텀블러 사용을 생활화하여 일회용품 사용을 줄이세요.
#         *   테이크아웃 대신 매장 내에서 머그컵을 이용하는 것을 고려해 보세요.
#         *   가끔은 다른 친환경적인 카페를 방문해 보세요.
#     *   감축률별 감축 예상량:
#         *   0% 감축: 0kgCO₂
#         *   5% 감축: 26.1kgCO₂
#         *   10% 감축: 52.2kgCO₂
#         *   15% 감축: 78.3kgCO₂
#
# *   **더벤티 (카페)**
#     *   현재 탄소 기여도: 478.4kgCO₂ (총 21744.0kgCO₂의 2.2%)
#     *   추천 감축률: 0% / 20% / 40% / 60% / 80%
#     *   실천 전략:
#         *   방문 횟수를 주 1~2회 줄여보세요.
#         *   텀블러 사용을 통해 일회용 컵 사용을 최소화하세요.
#         *   다른 저탄소 음료(예: 물, 차)로 대체하는 것을 고려해 보세요.
#     *   감축률별 감축 예상량:
#         *   0% 감축: 0kgCO₂
#         *   20% 감축: 95.7kgCO₂
#         *   40% 감축: 191.4kgCO₂
#         *   60% 감축: 287.0kgCO₂
#         *   80% 감축: 382.7kgCO₂
#
# *   **맥도날드 (음식점)**
#     *   현재 탄소 기여도: 457.0kgCO₂ (총 21744.0kgCO₂의 2.1%)
#     *   추천 감축률: 0% / 5% / 10% / 15%
#     *   실천 전략:
#         *   한 달에 1회 정도 방문 횟수를 줄여보세요.
#         *   세트 메뉴 대신 단품 메뉴를 선택하여 불필요한 소비를 줄이세요.
#         *   고기 패티 대신 식물성 패티 옵션을 고려해 보세요.
#     *   감축률별 감축 예상량:
#         *   0% 감축: 0kgCO₂
#         *   5% 감축: 22.9kgCO₂
#         *   10% 감축: 45.7kgCO₂
#         *   15% 감축: 68.6kgCO₂
#
# ## 5. [총 감축 효과 예측]
#
# 소비자 6님께서 위에서 제안된 감축률을 선택했을 때의 총 감축 효과를 예측해 보겠습니다.
#
# **예시 시나리오:**
#
# *   런던베이글: 20% 감축 선택
# *   (주)에이비카페: 10% 감축 선택
# *   쿰베오: 10% 감축 선택
# *   더벤티: 40% 감축 선택
# *   맥도날드: 10% 감축 선택
#
# **각 항목 감축률 선택 + 총 감축량 계산:**
#
# *   런던베이글: 1108.9kgCO₂ * 0.20 = 221.8kgCO₂
# *   (주)에이비카페: 804.5kgCO₂ * 0.10 = 80.5kgCO₂
# *   쿰베오: 521.9kgCO₂ * 0.10 = 52.2kgCO₂
# *   더벤티: 478.4kgCO₂ * 0.40 = 191.4kgCO₂
# *   맥도날드: 457.0kgCO₂ * 0.10 = 45.7kgCO₂
#
# **총 감축량:** 221.8 + 80.5 + 52.2 + 191.4 + 45.7 = **591.6kgCO₂**
#
# **감축 후 총 배출량:** 21744.0kgCO₂ - 591.6kgCO₂ = **21152.4kgCO₂**
#
# 이 시나리오대로 실천하시면 한 달에 약 591.6kgCO₂의 탄소를 감축하여, 총 탄소 배출량을 21152.4kgCO₂로 줄일 수 있습니다. 이는 약 27그루의 소나무가 1년간 흡수하는 탄소량과 맞먹는 효과입니다!
#
# ## 6. [마무리 코멘트]
#
# 소비자 6님, 탄소 감축을 위한 첫걸음을 내딛는 것은 매우 의미 있는 일입니다. 위에서 제안된 전략들을 한 번에 모두 실천하기보다는, 본인의 생활 패턴에 맞춰 실현 가능한 목표부터 설정하고 점진적으로 늘려나가는 것이 중요합니다. 작은 변화들이 모여 큰 감축 효과를 만들어낼 수 있습니다.
#
# 다음 달에도 소비 데이터를 분석하여 감축 효과를 확인하고, 더 나은 전략을 함께 모색해 나갈 수 있습니다. 지속 가능한 소비를 향한 소비자 6님의 노력을 응원합니다!
# --------------------------------------------------
#
# [Gemini 프롬프트 - member 7]
# 소비자 7의 한 달 소비 요약:
# - 총 지출: 1503864원, 총 탄소 배출: 12768.8kgCO₂
# - 탄소 감축 우선순위 Top 5 항목:
# • 런던베이글 (음식점): 탄소기여도 18.8%, 감축우선순위 점수 0.277, 추천 감축률 0% ~ 15% → 이유: 소비가 매우 일정하여 감축 여지가 낮습니다. (표준편차비: 0.33)
# • (주)에이비카페 (카페): 탄소기여도 21.3%, 감축우선순위 점수 0.262, 추천 감축률 0% ~ 15% → 이유: 소비가 매우 일정하여 감축 여지가 낮습니다. (표준편차비: 0.17)
# • 쿰베오 (카페): 탄소기여도 10.1%, 감축우선순위 점수 0.243, 추천 감축률 0% ~ 15% → 이유: 소비가 매우 일정하여 감축 여지가 낮습니다. (표준편차비: 0.27)
# • 메가커피 (카페): 탄소기여도 9.8%, 감축우선순위 점수 0.241, 추천 감축률 10% ~ 40% → 이유: 소비 변동성이 중간 수준이며, 10~40% 범위 감축이 가능합니다. (표준편차비: 0.54)
# • 더벤티 (카페): 탄소기여도 4.3%, 감축우선순위 점수 0.22, 추천 감축률 10% ~ 40% → 이유: 소비 변동성이 중간 수준이며, 10~40% 범위 감축이 가능합니다. (표준편차비: 0.52)
#
# 이 소비자에게 탄소 감축을 위해 어떤 실천 전략이 가장 효과적일까요?
# 항목별로 감축률을 선택할 수 있게 유도하고, 총 감축 효과가 얼마나 될지도 예측해주세요.
# 다음과 같은 형식에 맞춰 구체적으로 답변해 주세요. 반드시 아래 구조를 따르되, 내용은 소비자 특성에 맞게 맞춤화해 주세요:
#
#
#     1. 소비자 인삿말 및 분석 요약
#
#     2. [현재 소비 패턴 분석]
#     - 총지출 대비 탄소 배출량 특이점
#     - 어떤 업종/브랜드가 주요 기여자인지
#     - 탄소 감축 가능성이 있는 소비 패턴
#     - 추천 감축률이 낮은 이유 (ex: 소비 기록 적음)
#
#     3. [감축 전략 제안]
#     - 외식/문화 등 업종별 구체적 조언 포함
#     - 실천 가능한 행동 위주로 제안
#
#     4. [Top 5 항목별 감축률 가이드]
#     아래 형식을 반복해서 제시:
#     - 브랜드명 (업종)
#     - 현재 탄소 기여도 (kgCO₂)
#     - 추천 감축률 (예: 0% / 5% / 10% / 20% / 30%)
#     - 실천 전략 (bullet 2~3개)
#     - 감축률별 감축 예상량 (계산 기반)
#
#     5. [총 감축 효과 예측]
#     - 예시 시나리오 제시
#     - 각 항목 감축률 선택 + 총 감축량 계산
#     - 감축 후 총 배출량 제시
#
#     6. [마무리 코멘트]
#     - 긍정적인 격려
#     - 다음 단계 제안
#
#     **반드시 위 양식을 지켜 작성해주세요.**
#
# [Gemini 응답 - member 7]
# 안녕하세요, 소비자 7님! 한 달간의 소비 데이터를 바탕으로 탄소 감축을 위한 맞춤형 전략을 제안해 드립니다.
#
# ### 1. 소비자 인삿말 및 분석 요약
#
# 소비자 7님께서는 한 달간 총 1,503,864원을 지출하셨고, 이로 인해 12,768.8kgCO₂의 탄소를 배출하셨습니다. 특히 카페와 음식점에서의 소비가 탄소 배출에 큰 비중을 차지하고 있습니다. 이번 분석을 통해 소비자 7님의 소비 패턴을 이해하고, 효과적인 탄소 감축 방안을 함께 모색해보고자 합니다.
#
# ### 2. [현재 소비 패턴 분석]
#
# *   **총지출 대비 탄소 배출량 특이점**: 소비자 7님의 총 지출액 대비 탄소 배출량은 일반적인 소비 패턴과 비교했을 때, 특히 외식 및 카페 이용이 잦아 해당 부문에서 탄소 배출 비중이 높게 나타나는 경향이 있습니다. 이는 식음료 소비가 일상생활에서 큰 부분을 차지하고 있음을 시사합니다.
#
# *   **어떤 업종/브랜드가 주요 기여자인지**: 탄소 배출의 주요 기여자는 '카페'와 '음식점' 업종입니다. 특히 **(주)에이비카페 (21.3%)**, **런던베이글 (18.8%)**, **쿰베오 (10.1%)**, **메가커피 (9.8%)**, **더벤티 (4.3%)** 순으로 탄소 기여도가 높게 나타났습니다. 상위 5개 항목이 전체 탄소 배출량의 약 64.3%를 차지하고 있어, 이들 브랜드에서의 소비 조절이 탄소 감축에 매우 효과적일 것으로 보입니다.
#
# *   **탄소 감축 가능성이 있는 소비 패턴**: 메가커피와 더벤티의 경우 소비 변동성이 중간 수준으로 나타나, 10%~40% 범위의 감축이 가능하다고 분석되었습니다. 이는 해당 브랜드에서의 소비를 조금만 조절해도 유의미한 탄소 감축 효과를 볼 수 있음을 의미합니다.
#
# *   **추천 감축률이 낮은 이유**: 런던베이글, (주)에이비카페, 쿰베오의 경우 소비가 매우 일정하여 감축 여지가 낮다고 분석되었습니다. 이는 해당 브랜드에 대한 소비가 습관화되어 있거나, 특정 목적을 가지고 꾸준히 이용하는 경향이 강하기 때문으로 보입니다. 따라서 이들 브랜드에서는 급격한 소비 변화보다는 점진적인 노력이 필요합니다.
#
# ### 3. [감축 전략 제안]
#
# 소비자 7님의 탄소 감축을 위해 다음과 같은 실천 전략을 제안합니다.
#
# *   **외식/카페 소비 조절**:
#     *   **카페 이용 습관 개선**: 매일 방문하는 카페 대신 주 2~3회로 줄이거나, 테이크아웃 시 개인 컵을 사용하는 습관을 들여보세요.
#     *   **메뉴 선택의 변화**: 고기류 위주의 식사보다는 채식 위주의 메뉴를 선택하는 날을 늘려보세요. 채식은 탄소 배출량이 훨씬 적습니다.
#     *   **불필요한 외식 줄이기**: 주 1회 정도는 집에서 직접 요리하여 식사하는 날을 정해보세요. 직접 요리하면 식재료 선택부터 음식물 쓰레기까지 탄소 배출을 줄일 수 있습니다.
# *   **대체 소비 고려**:
#     *   자주 방문하는 카페나 음식점 중 탄소 배출량이 높은 곳 대신, 친환경적인 대안을 찾아보세요. 예를 들어, 로컬 푸드를 사용하는 식당이나 제로 웨이스트 카페를 이용하는 것도 좋은 방법입니다.
# *   **소비 기록 및 목표 설정**:
#     *   자신의 소비 패턴을 주기적으로 확인하고, 매월 탄소 감축 목표를 설정하여 달성 여부를 확인하는 것이 중요합니다.
#
# ### 4. [Top 5 항목별 감축률 가이드]
#
# 각 항목별로 현재 탄소 기여도와 추천 감축률, 그리고 실천 전략을 제시합니다. 감축률 선택에 따라 예상되는 탄소 감축량을 확인해보세요.
#
# *   **런던베이글 (음식점)**
#     *   현재 탄소 기여도: 12,768.8kgCO₂ * 18.8% = 2,400.5kgCO₂
#     *   추천 감축률: 0% / 5% / 10%
#     *   실천 전략:
#         *   방문 횟수를 주 1회 줄여보세요.
#         *   포장 시 다회용 용기를 사용해보세요.
#         *   베이글 구매 시 불필요한 포장재 사용을 줄여달라고 요청해보세요.
#     *   감축률별 감축 예상량:
#         *   0% 감축: 0kgCO₂
#         *   5% 감축: 120.0kgCO₂
#         *   10% 감축: 240.1kgCO₂
#
# *   **(주)에이비카페 (카페)**
#     *   현재 탄소 기여도: 12,768.8kgCO₂ * 21.3% = 2,718.4kgCO₂
#     *   추천 감축률: 0% / 5% / 10%
#     *   실천 전략:
#         *   개인 컵을 사용하여 음료를 구매하고 할인 혜택을 받아보세요.
#         *   주 1회 정도는 카페 방문 대신 집에서 커피를 내려 마셔보세요.
#         *   우유가 들어간 음료 대신 아메리카노나 차 종류를 선택해보세요.
#     *   감축률별 감축 예상량:
#         *   0% 감축: 0kgCO₂
#         *   5% 감축: 135.9kgCO₂
#         *   10% 감축: 271.8kgCO₂
#
# *   **쿰베오 (카페)**
#     *   현재 탄소 기여도: 12,768.8kgCO₂ * 10.1% = 1,289.6kgCO₂
#     *   추천 감축률: 0% / 5% / 10%
#     *   실천 전략:
#         *   개인 컵 사용을 생활화하여 일회용품 사용을 줄여보세요.
#         *   카페 방문 시 대중교통을 이용하거나 걸어가 보세요.
#         *   불필요한 추가 주문(예: 디저트)을 줄여보세요.
#     *   감축률별 감축 예상량:
#         *   0% 감축: 0kgCO₂
#         *   5% 감축: 64.5kgCO₂
#         *   10% 감축: 129.0kgCO₂
#
# *   **메가커피 (카페)**
#     *   현재 탄소 기여도: 12,768.8kgCO₂ * 9.8% = 1,251.3kgCO₂
#     *   추천 감축률: 10% / 20% / 30% / 40%
#     *   실천 전략:
#         *   주 1~2회 방문 횟수를 줄여보세요.
#         *   대용량 음료 대신 일반 사이즈를 선택해보세요.
#         *   테이크아웃 시 개인 컵을 사용하고, 매장 내에서 마실 경우 머그컵을 요청하세요.
#     *   감축률별 감축 예상량:
#         *   10% 감축: 125.1kgCO₂
#         *   20% 감축: 250.3kgCO₂
#         *   30% 감축: 375.4kgCO₂
#         *   40% 감축: 500.5kgCO₂
#
# *   **더벤티 (카페)**
#     *   현재 탄소 기여도: 12,768.8kgCO₂ * 4.3% = 549.1kgCO₂
#     *   추천 감축률: 10% / 20% / 30% / 40%
#     *   실천 전략:
#         *   주 1회 정도는 방문을 자제하고 다른 대안을 찾아보세요.
#         *   개인 컵 사용을 통해 일회용품 사용을 줄여보세요.
#         *   음료 주문 시 얼음 양을 줄여 불필요한 낭비를 막아보세요.
#     *   감축률별 감축 예상량:
#         *   10% 감축: 54.9kgCO₂
#         *   20% 감축: 109.8kgCO₂
#         *   30% 감축: 164.7kgCO₂
#         *   40% 감축: 219.6kgCO₂
#
# ### 5. [총 감축 효과 예측]
#
# 소비자 7님께서 위 가이드를 바탕으로 다음과 같이 감축률을 선택한다고 가정해 봅시다.
#
# *   런던베이글: 5% 감축 (120.0kgCO₂ 감축)
# *   (주)에이비카페: 5% 감축 (135.9kgCO₂ 감축)
# *   쿰베오: 5% 감축 (64.5kgCO₂ 감축)
# *   메가커피: 20% 감축 (250.3kgCO₂ 감축)
# *   더벤티: 20% 감축 (109.8kgCO₂ 감축)
#
# **총 감축량 계산:**
# 120.0kgCO₂ + 135.9kgCO₂ + 64.5kgCO₂ + 250.3kgCO₂ + 109.8kgCO₂ = **680.5kgCO₂**
#
# **감축 후 총 배출량:**
# 12,768.8kgCO₂ - 680.5kgCO₂ = **12,088.3kgCO₂**
#
# 이 시나리오대로 실천하시면 한 달에 약 680.5kgCO₂의 탄소를 감축하여, 총 탄소 배출량을 12,088.3kgCO₂로 줄일 수 있습니다. 이는 약 5.3%의 탄소 감축 효과에 해당합니다.
#
# ### 6. [마무리 코멘트]
#
# 소비자 7님, 작은 변화들이 모여 큰 차이를 만들어낼 수 있습니다. 위에서 제안 드린 전략들을 꾸준히 실천하시면 환경 보호에 크게 기여하실 수 있을 것입니다. 처음에는 어렵게 느껴질 수 있지만, 하나씩 시도해보면서 자신에게 맞는 방법을 찾아가는 것이 중요합니다.
#
# 다음 달에는 감축된 탄소 배출량을 확인하고, 더 나아가 다른 소비 항목에서도 탄소 감축 기회를 찾아보는 것을 추천합니다. 소비자 7님의 지속적인 노력을 응원합니다!
# --------------------------------------------------
#
# [Gemini 프롬프트 - member 8]
# 소비자 8의 한 달 소비 요약:
# - 총 지출: 2976358원, 총 탄소 배출: 8956.8kgCO₂
# - 탄소 감축 우선순위 Top 5 항목:
# • (주)에이비카페 (카페): 탄소기여도 6.3%, 감축우선순위 점수 0.227, 추천 감축률 0% ~ 15% → 이유: 소비가 매우 일정하여 감축 여지가 낮습니다. (표준편차비: 0.40)
# • 런던베이글 (음식점): 탄소기여도 2.8%, 감축우선순위 점수 0.213, 추천 감축률 0% ~ 10% → 이유: 해당 브랜드의 소비 기록이 적어, 안전하게 0~10% 감축만 권장됩니다.
# • 코스트코 (대형마트): 탄소기여도 32.0%, 감축우선순위 점수 0.129, 추천 감축률 0% ~ 15% → 이유: 소비가 매우 일정하여 감축 여지가 낮습니다. (표준편차비: 0.31)
# • 이마트 (대형마트): 탄소기여도 22.0%, 감축우선순위 점수 0.089, 추천 감축률 0% ~ 15% → 이유: 소비가 매우 일정하여 감축 여지가 낮습니다. (표준편차비: 0.17)
# • 세븐일레븐 (편의점): 탄소기여도 9.5%, 감축우선순위 점수 0.039, 추천 감축률 0% ~ 15% → 이유: 소비가 매우 일정하여 감축 여지가 낮습니다. (표준편차비: 0.21)
#
# 이 소비자에게 탄소 감축을 위해 어떤 실천 전략이 가장 효과적일까요?
# 항목별로 감축률을 선택할 수 있게 유도하고, 총 감축 효과가 얼마나 될지도 예측해주세요.
# 다음과 같은 형식에 맞춰 구체적으로 답변해 주세요. 반드시 아래 구조를 따르되, 내용은 소비자 특성에 맞게 맞춤화해 주세요:
#
#
#     1. 소비자 인삿말 및 분석 요약
#
#     2. [현재 소비 패턴 분석]
#     - 총지출 대비 탄소 배출량 특이점
#     - 어떤 업종/브랜드가 주요 기여자인지
#     - 탄소 감축 가능성이 있는 소비 패턴
#     - 추천 감축률이 낮은 이유 (ex: 소비 기록 적음)
#
#     3. [감축 전략 제안]
#     - 외식/문화 등 업종별 구체적 조언 포함
#     - 실천 가능한 행동 위주로 제안
#
#     4. [Top 5 항목별 감축률 가이드]
#     아래 형식을 반복해서 제시:
#     - 브랜드명 (업종)
#     - 현재 탄소 기여도 (kgCO₂)
#     - 추천 감축률 (예: 0% / 5% / 10% / 20% / 30%)
#     - 실천 전략 (bullet 2~3개)
#     - 감축률별 감축 예상량 (계산 기반)
#
#     5. [총 감축 효과 예측]
#     - 예시 시나리오 제시
#     - 각 항목 감축률 선택 + 총 감축량 계산
#     - 감축 후 총 배출량 제시
#
#     6. [마무리 코멘트]
#     - 긍정적인 격려
#     - 다음 단계 제안
#
#     **반드시 위 양식을 지켜 작성해주세요.**
#
# [Gemini 응답 - member 8]
# ## 1. 소비자 인삿말 및 분석 요약
#
# 안녕하세요, 소비자 8님! 한 달간의 소비 데이터를 분석하여 탄소 감축을 위한 맞춤형 전략을 제안해 드립니다. 현재 총 지출 2,976,358원에 총 탄소 배출량은 8,956.8kgCO₂로 나타났습니다. 특히 대형마트와 편의점 등 일상 소비처에서 높은 탄소 기여도를 보이고 있습니다.
#
# ## 2. [현재 소비 패턴 분석]
#
# *   **총지출 대비 탄소 배출량 특이점**: 총 지출액이 높은 편이며, 이에 비례하여 탄소 배출량도 상당한 수준입니다. 특히 식료품 및 생활용품 구매가 많은 대형마트와 편의점에서의 소비가 탄소 배출의 큰 부분을 차지하고 있습니다.
# *   **어떤 업종/브랜드가 주요 기여자인지**:
#     *   **코스트코 (대형마트)**: 32.0%
#     *   **이마트 (대형마트)**: 22.0%
#     *   **세븐일레븐 (편의점)**: 9.5%
#     *   이 세 곳이 전체 탄소 배출량의 63.5%를 차지하며, 소비자 8님의 탄소 배출에 가장 큰 영향을 미치는 주요 기여자입니다.
#     *   (주)에이비카페와 런던베이글도 각각 6.3%, 2.8%로 일정 부분 기여하고 있습니다.
# *   **탄소 감축 가능성이 있는 소비 패턴**: 대형마트와 편의점에서의 소비가 매우 일정하여 감축 여지가 낮다고 분석되었지만, 이는 소비 습관이 고정적이라는 의미이기도 합니다. 따라서 소비 품목을 친환경 제품으로 대체하거나, 불필요한 구매를 줄이는 등의 노력을 통해 충분히 감축 효과를 볼 수 있습니다.
# *   **추천 감축률이 낮은 이유**: 대부분의 항목에서 소비가 매우 일정하여 표준편차비가 낮게 나타났습니다. 이는 소비 패턴이 예측 가능하고 안정적이라는 장점이 있지만, 동시에 급격한 소비 변화를 통한 감축보다는 점진적이고 꾸준한 노력이 필요함을 시사합니다. 런던베이글의 경우 소비 기록이 적어 보수적인 감축률이 권장되었습니다.
#
# ## 3. [감축 전략 제안]
#
# 소비자 8님의 소비 패턴을 고려할 때, 일상생활 속 작은 변화들이 큰 감축 효과를 가져올 수 있습니다.
#
# *   **식료품/생활용품 구매**:
#     *   **대형마트/편의점 방문 시**: 구매 목록을 미리 작성하여 불필요한 충동구매를 줄이고, 과대 포장된 제품보다는 친환경 포장 제품이나 리필 가능한 제품을 선택해 보세요.
#     *   **식단 변화**: 육류 소비를 줄이고 채식 위주의 식단을 늘리는 것은 탄소 배출 감축에 매우 효과적입니다. 주 1~2회 채식의 날을 정해보는 것도 좋습니다.
#     *   **음식물 쓰레기 줄이기**: 필요한 만큼만 구매하고, 남은 음식은 재활용하거나 퇴비화하는 등 음식물 쓰레기를 최소화하는 노력이 필요합니다.
# *   **외식/카페 이용**:
#     *   **개인 컵 사용**: 카페 이용 시 개인 컵을 사용하면 일회용 컵 사용으로 인한 탄소 배출을 줄일 수 있습니다.
#     *   **포장 용기 지참**: 음식 포장 시 다회용 용기를 지참하는 습관을 들여보세요.
# *   **기타 생활 습관**:
#     *   **대중교통 이용 및 걷기**: 가까운 거리는 걷거나 자전거를 이용하고, 대중교통을 적극적으로 활용하여 차량 이용을 줄여보세요.
#     *   **에너지 절약**: 사용하지 않는 전등 끄기, 플러그 뽑기, 냉난방 온도 적정 유지 등 가정 내 에너지 절약도 중요합니다.
#
# ## 4. [Top 5 항목별 감축률 가이드]
#
# 각 항목별로 현재 탄소 기여도와 추천 감축률, 그리고 실천 전략을 제안해 드립니다. 제시된 감축률 중 소비자 8님께서 실천 가능한 수준을 선택해 보세요.
#
# *   **코스트코 (대형마트)**
#     *   현재 탄소 기여도: 2866.2kgCO₂ (32.0%)
#     *   추천 감축률: 0% / 5% / 10% / 15%
#     *   실천 전략:
#         *   구매 전 필요한 물품 목록을 작성하고, 계획에 없는 충동구매를 자제합니다.
#         *   과대 포장된 제품 대신 친환경 포장 제품이나 리필 가능한 대용량 제품을 선택합니다.
#         *   육류 구매량을 줄이고, 채소/과일 등 식물성 식품 구매 비중을 늘립니다.
#     *   감축률별 감축 예상량:
#         *   0% 감축: 0kgCO₂
#         *   5% 감축: 143.31kgCO₂
#         *   10% 감축: 286.62kgCO₂
#         *   15% 감축: 429.93kgCO₂
#
# *   **이마트 (대형마트)**
#     *   현재 탄소 기여도: 1970.5kgCO₂ (22.0%)
#     *   추천 감축률: 0% / 5% / 10% / 15%
#     *   실천 전략:
#         *   장보기 전 냉장고를 확인하여 중복 구매를 피하고, 유통기한이 임박한 식품을 먼저 소비합니다.
#         *   개인 장바구니를 항상 지참하여 비닐봉투 사용을 줄입니다.
#         *   로컬푸드나 제철 식품을 구매하여 운송 과정에서 발생하는 탄소 배출을 줄입니다.
#     *   감축률별 감축 예상량:
#         *   0% 감축: 0kgCO₂
#         *   5% 감축: 98.525kgCO₂
#         *   10% 감축: 197.05kgCO₂
#         *   15% 감축: 295.575kgCO₂
#
# *   **세븐일레븐 (편의점)**
#     *   현재 탄소 기여도: 850.9kgCO₂ (9.5%)
#     *   추천 감축률: 0% / 5% / 10% / 15%
#     *   실천 전략:
#         *   불필요한 간식이나 음료 구매를 줄이고, 집에서 직접 준비한 간식을 이용합니다.
#         *   일회용품 사용이 많은 편의점 도시락, 컵라면 대신 집밥을 선호합니다.
#         *   개인 컵이나 텀블러를 사용하여 편의점 커피 구매 시 일회용 컵 사용을 줄입니다.
#     *   감축률별 감축 예상량:
#         *   0% 감축: 0kgCO₂
#         *   5% 감축: 42.545kgCO₂
#         *   10% 감축: 85.09kgCO₂
#         *   15% 감축: 127.635kgCO₂
#
# *   **(주)에이비카페 (카페)**
#     *   현재 탄소 기여도: 564.3kgCO₂ (6.3%)
#     *   추천 감축률: 0% / 5% / 10% / 15%
#     *   실천 전략:
#         *   카페 방문 시 개인 컵이나 텀블러를 사용하여 일회용 컵 사용을 줄입니다.
#         *   테이크아웃보다는 매장 내에서 머그컵을 이용합니다.
#         *   커피 외에 탄소 배출량이 적은 차 종류를 선택하는 것도 고려해 봅니다.
#     *   감축률별 감축 예상량:
#         *   0% 감축: 0kgCO₂
#         *   5% 감축: 28.215kgCO₂
#         *   10% 감축: 56.43kgCO₂
#         *   15% 감축: 84.645kgCO₂
#
# *   **런던베이글 (음식점)**
#     *   현재 탄소 기여도: 250.8kgCO₂ (2.8%)
#     *   추천 감축률: 0% / 5% / 10%
#     *   실천 전략:
#         *   외식 시 남기지 않을 만큼만 주문하여 음식물 쓰레기를 줄입니다.
#         *   포장 시 다회용 용기를 지참하여 일회용 포장재 사용을 줄입니다.
#         *   가급적 채식 메뉴를 선택하거나, 육류가 적게 들어간 메뉴를 선택합니다.
#     *   감축률별 감축 예상량:
#         *   0% 감축: 0kgCO₂
#         *   5% 감축: 12.54kgCO₂
#         *   10% 감축: 25.08kgCO₂
#
# ## 5. [총 감축 효과 예측]
#
# 소비자 8님께서 각 항목별로 다음과 같이 감축률을 선택한다고 가정해 보겠습니다.
#
# *   코스트코 (대형마트): 10% 감축
# *   이마트 (대형마트): 10% 감축
# *   세븐일레븐 (편의점): 10% 감축
# *   (주)에이비카페 (카페): 10% 감축
# *   런던베이글 (음식점): 5% 감축
#
# **총 감축량 계산:**
#
# *   코스트코: 286.62kgCO₂
# *   이마트: 197.05kgCO₂
# *   세븐일레븐: 85.09kgCO₂
# *   (주)에이비카페: 56.43kgCO₂
# *   런던베이글: 12.54kgCO₂
#
# **총 예상 감축량:** 286.62 + 197.05 + 85.09 + 56.43 + 12.54 = **637.73kgCO₂**
#
# **감축 후 총 배출량:** 8956.8kgCO₂ - 637.73kgCO₂ = **8319.07kgCO₂**
#
# 이 시나리오대로 실천하시면 한 달에 약 637.73kgCO₂의 탄소를 감축하여, 총 탄소 배출량을 8319.07kgCO₂로 줄일 수 있습니다. 이는 약 7.1%의 탄소 감축 효과를 가져옵니다.
#
# ## 6. [마무리 코멘트]
#
# 소비자 8님, 현재 소비 패턴이 일정하여 감축 여지가 낮다는 분석은 오히려 꾸준한 노력을 통해 안정적인 감축 효과를 기대할 수 있다는 긍정적인 신호입니다. 대형마트와 편의점에서의 작은 변화들이 모여 큰 탄소 감축 효과를 가져올 수 있습니다.
#
# 오늘 제안해 드린 전략들을 바탕으로, 소비자 8님의 라이프스타일에 맞춰 실천 가능한 목표를 세워보세요. 작은 실천들이 모여 지구를 위한 큰 변화를 만들 수 있습니다. 다음 달에는 더욱 줄어든 탄소 배출량을 확인할 수 있기를 기대합니다!
# --------------------------------------------------
#
# [Gemini 프롬프트 - member 9]
# 소비자 9의 한 달 소비 요약:
# - 총 지출: 4650108원, 총 탄소 배출: 19967.3kgCO₂
# - 탄소 감축 우선순위 Top 5 항목:
# • 런던베이글 (음식점): 탄소기여도 11.0%, 감축우선순위 점수 0.246, 추천 감축률 0% ~ 15% → 이유: 소비가 매우 일정하여 감축 여지가 낮습니다. (표준편차비: 0.17)
# • (주)에이비카페 (카페): 탄소기여도 4.7%, 감축우선순위 점수 0.221, 추천 감축률 0% ~ 15% → 이유: 소비가 매우 일정하여 감축 여지가 낮습니다. (표준편차비: 0.11)
# • 맥도날드 (음식점): 탄소기여도 3.0%, 감축우선순위 점수 0.214, 추천 감축률 20% ~ 80% → 이유: 소비 변동성이 매우 크기 때문에, 최대 80%까지도 감축 가능합니다. (표준편차비: 0.89)
# • 쿰베오 (카페): 탄소기여도 0.6%, 감축우선순위 점수 0.205, 추천 감축률 0% ~ 10% → 이유: 해당 브랜드의 소비 기록이 적어, 안전하게 0~10% 감축만 권장됩니다.
# • 세인트존스호텔 (숙박): 탄소기여도 43.5%, 감축우선순위 점수 0.176, 추천 감축률 10% ~ 40% → 이유: 소비 변동성이 중간 수준이며, 10~40% 범위 감축이 가능합니다. (표준편차비: 0.50)
#
# 이 소비자에게 탄소 감축을 위해 어떤 실천 전략이 가장 효과적일까요?
# 항목별로 감축률을 선택할 수 있게 유도하고, 총 감축 효과가 얼마나 될지도 예측해주세요.
# 다음과 같은 형식에 맞춰 구체적으로 답변해 주세요. 반드시 아래 구조를 따르되, 내용은 소비자 특성에 맞게 맞춤화해 주세요:
#
#
#     1. 소비자 인삿말 및 분석 요약
#
#     2. [현재 소비 패턴 분석]
#     - 총지출 대비 탄소 배출량 특이점
#     - 어떤 업종/브랜드가 주요 기여자인지
#     - 탄소 감축 가능성이 있는 소비 패턴
#     - 추천 감축률이 낮은 이유 (ex: 소비 기록 적음)
#
#     3. [감축 전략 제안]
#     - 외식/문화 등 업종별 구체적 조언 포함
#     - 실천 가능한 행동 위주로 제안
#
#     4. [Top 5 항목별 감축률 가이드]
#     아래 형식을 반복해서 제시:
#     - 브랜드명 (업종)
#     - 현재 탄소 기여도 (kgCO₂)
#     - 추천 감축률 (예: 0% / 5% / 10% / 20% / 30%)
#     - 실천 전략 (bullet 2~3개)
#     - 감축률별 감축 예상량 (계산 기반)
#
#     5. [총 감축 효과 예측]
#     - 예시 시나리오 제시
#     - 각 항목 감축률 선택 + 총 감축량 계산
#     - 감축 후 총 배출량 제시
#
#     6. [마무리 코멘트]
#     - 긍정적인 격려
#     - 다음 단계 제안
#
#     **반드시 위 양식을 지켜 작성해주세요.**
#
# [Gemini 응답 - member 9]
# ## 1. 소비자 인삿말 및 분석 요약
#
# 안녕하세요, 소비자 9님! 한 달간의 소비 데이터를 바탕으로 탄소 배출 현황을 분석해 드렸습니다. 총 지출 4,650,108원에 총 19,967.3kgCO₂의 탄소를 배출하셨습니다. 특히 숙박과 외식 부문에서 탄소 배출 비중이 높은 것으로 나타났습니다.
#
# 이번 분석을 통해 소비자 9님의 소비 패턴에 맞는 효과적인 탄소 감축 전략을 제안해 드리고자 합니다. 몇 가지 작은 변화만으로도 의미 있는 탄소 감축 효과를 얻으실 수 있을 거예요.
#
# ## 2. [현재 소비 패턴 분석]
#
# *   **총지출 대비 탄소 배출량 특이점**: 소비자 9님의 총 지출액 대비 탄소 배출량은 꽤 높은 편입니다. 특히 '세인트존스호텔'과 같은 숙박 시설 이용이 전체 탄소 배출량의 43.5%를 차지하며 압도적인 비중을 보이고 있습니다. 이는 일상적인 소비 외에 특정 고탄소 활동이 전체 배출량에 큰 영향을 미치고 있음을 시사합니다.
#
# *   **어떤 업종/브랜드가 주요 기여자인지**:
#     *   **숙박**: 세인트존스호텔 (43.5%)이 단연 가장 큰 기여를 하고 있습니다.
#     *   **음식점**: 런던베이글 (11.0%), 맥도날드 (3.0%)가 주요 기여 브랜드입니다.
#     *   **카페**: (주)에이비카페 (4.7%), 쿰베오 (0.6%)가 뒤를 잇습니다.
#
# *   **탄소 감축 가능성이 있는 소비 패턴**:
#     *   **맥도날드 (음식점)**: 소비 변동성이 매우 커서 최대 80%까지 감축 가능성이 높습니다. 이는 특정 시기에 집중적으로 소비하거나, 대체 가능한 외식 옵션이 많다는 것을 의미할 수 있습니다.
#     *   **세인트존스호텔 (숙박)**: 탄소 기여도가 매우 높고 소비 변동성이 중간 수준이므로, 계획적인 감축 노력을 통해 큰 효과를 볼 수 있습니다.
#
# *   **추천 감축률이 낮은 이유**:
#     *   **런던베이글, (주)에이비카페**: 소비가 매우 일정하여 감축 여지가 낮다고 판단되었습니다. 이는 해당 브랜드가 소비자 9님의 일상생활에 깊이 자리 잡은 루틴 소비일 가능성이 높습니다.
#     *   **쿰베오**: 해당 브랜드의 소비 기록이 적어, 데이터 부족으로 인해 안전하게 낮은 감축률만 권장되었습니다.
#
# ## 3. [감축 전략 제안]
#
# 소비자 9님의 탄소 감축을 위한 실천 전략은 크게 두 가지 방향으로 제안합니다. 첫째, 탄소 기여도가 가장 높은 숙박 부문의 소비를 신중하게 고려하는 것입니다. 둘째, 외식 및 카페 이용 습관에서 작은 변화를 주는 것입니다.
#
# *   **숙박**: 장거리 여행 시 대중교통 이용을 고려하거나, 친환경 인증을 받은 숙소를 선택하는 것도 좋은 방법입니다. 숙박 일수를 줄이거나, 불필요한 숙박을 자제하는 것이 가장 효과적입니다.
# *   **외식**:
#     *   **맥도날드**: 소비 변동성이 크므로, 외식 빈도를 줄이거나 채식 메뉴를 선택하는 등 의식적인 노력을 통해 감축 효과를 극대화할 수 있습니다.
#     *   **런던베이글**: 일상적인 소비이므로, 포장 시 개인 용기를 사용하거나, 불필요한 일회용품 사용을 줄이는 등 작은 습관 변화를 시도해 보세요.
# *   **카페**:
#     *   **(주)에이비카페, 쿰베오**: 개인 컵 사용을 생활화하여 일회용 컵 사용을 줄이는 것이 가장 쉽고 효과적인 방법입니다.
#
# ## 4. [Top 5 항목별 감축률 가이드]
#
# 각 항목별로 현재 탄소 기여도를 바탕으로 추천 감축률과 실천 전략, 그리고 예상 감축량을 제시해 드립니다.
#
# ---
#
# *   **런던베이글 (음식점)**
#     *   현재 탄소 기여도: 2196.4kgCO₂ (총 19967.3kgCO₂의 11.0%)
#     *   추천 감축률: 0% / 5% / 10%
#     *   실천 전략:
#         *   매장 이용 시 개인 컵/텀블러 사용하기
#         *   포장 시 개인 용기 지참하기
#         *   불필요한 일회용품(냅킨, 물티슈 등) 사용 줄이기
#     *   감축률별 감축 예상량:
#         *   0% 감축: 0kgCO₂
#         *   5% 감축: 109.8kgCO₂
#         *   10% 감축: 219.6kgCO₂
#
# ---
#
# *   **(주)에이비카페 (카페)**
#     *   현재 탄소 기여도: 938.5kgCO₂ (총 19967.3kgCO₂의 4.7%)
#     *   추천 감축률: 0% / 5% / 10%
#     *   실천 전략:
#         *   개인 컵/텀블러 사용을 생활화하여 일회용 컵 사용 줄이기
#         *   빨대 등 플라스틱 사용 자제하기
#         *   커피 찌꺼기 재활용 캠페인 참여하기
#     *   감축률별 감축 예상량:
#         *   0% 감축: 0kgCO₂
#         *   5% 감축: 46.9kgCO₂
#         *   10% 감축: 93.8kgCO₂
#
# ---
#
# *   **맥도날드 (음식점)**
#     *   현재 탄소 기여도: 599.0kgCO₂ (총 19967.3kgCO₂의 3.0%)
#     *   추천 감축률: 20% / 40% / 60% / 80%
#     *   실천 전략:
#         *   외식 빈도를 줄이고 집에서 직접 요리하기
#         *   맥도날드 방문 시 채식 옵션(샐러드, 사이드 메뉴 등) 선택하기
#         *   불필요한 포장재나 일회용품 사용 줄이기
#     *   감축률별 감축 예상량:
#         *   20% 감축: 119.8kgCO₂
#         *   40% 감축: 239.6kgCO₂
#         *   60% 감축: 359.4kgCO₂
#         *   80% 감축: 479.2kgCO₂
#
# ---
#
# *   **쿰베오 (카페)**
#     *   현재 탄소 기여도: 119.8kgCO₂ (총 19967.3kgCO₂의 0.6%)
#     *   추천 감축률: 0% / 5% / 10%
#     *   실천 전략:
#         *   개인 컵/텀블러 사용으로 일회용 컵 사용 줄이기
#         *   매장 내에서 머그컵 이용하기
#         *   불필요한 빨대, 컵 홀더 등 사용 자제하기
#     *   감축률별 감축 예상량:
#         *   0% 감축: 0kgCO₂
#         *   5% 감축: 5.99kgCO₂
#         *   10% 감축: 11.98kgCO₂
#
# ---
#
# *   **세인트존스호텔 (숙박)**
#     *   현재 탄소 기여도: 8685.5kgCO₂ (총 19967.3kgCO₂의 43.5%)
#     *   추천 감축률: 10% / 20% / 30% / 40%
#     *   실천 전략:
#         *   불필요한 숙박 자제 및 숙박 일수 줄이기
#         *   여행 시 대중교통 이용 고려하기
#         *   친환경 인증을 받은 숙소 선택하기
#         *   숙소 내 에너지 절약(불 끄기, 냉난방 적정 온도 유지) 실천하기
#     *   감축률별 감축 예상량:
#         *   10% 감축: 868.55kgCO₂
#         *   20% 감축: 1737.1kgCO₂
#         *   30% 감축: 2605.65kgCO₂
#         *   40% 감축: 3474.2kgCO₂
#
# ## 5. [총 감축 효과 예측]
#
# 소비자 9님께서 아래와 같이 감축률을 선택하신다면, 총 감축 효과는 다음과 같습니다.
#
# **예시 시나리오:**
#
# *   런던베이글: 5% 감축
# *   (주)에이비카페: 5% 감축
# *   맥도날드: 40% 감축
# *   쿰베오: 5% 감축
# *   세인트존스호텔: 20% 감축
#
# **각 항목 감축량 계산:**
#
# *   런던베이글: 2196.4kgCO₂ * 0.05 = 109.82kgCO₂
# *   (주)에이비카페: 938.5kgCO₂ * 0.05 = 46.925kgCO₂
# *   맥도날드: 599.0kgCO₂ * 0.40 = 239.6kgCO₂
# *   쿰베오: 119.8kgCO₂ * 0.05 = 5.99kgCO₂
# *   세인트존스호텔: 8685.5kgCO₂ * 0.20 = 1737.1kgCO₂
#
# **총 감축량:** 109.82 + 46.925 + 239.6 + 5.99 + 1737.1 = **2139.435kgCO₂**
#
# **감축 후 총 배출량:** 19967.3kgCO₂ - 2139.435kgCO₂ = **17827.865kgCO₂**
#
# 이 시나리오대로 실천하시면 한 달에 약 2.1톤의 탄소를 감축하실 수 있습니다! 이는 상당한 양의 탄소 감축 효과를 가져올 수 있습니다.
#
# ## 6. [마무리 코멘트]
#
# 소비자 9님, 탄소 감축은 거창한 일이 아니라 일상 속 작은 실천에서 시작됩니다. 특히 숙박과 외식 습관에서 조금만 더 신경 쓰신다면 큰 변화를 만들 수 있습니다. 오늘 제안 드린 전략들을 바탕으로 소비자 9님께 가장 적합한 감축 목표를 세워보세요.
#
# 다음 달에는 감축 목표 달성 여부를 함께 확인하고, 더 나은 탄소 감축 방안을 모색해 드릴 수 있도록 노력하겠습니다. 지속적인 관심과 실천으로 더 푸른 지구를 만드는 데 동참해 주셔서 감사합니다!
# --------------------------------------------------
#
# [Gemini 프롬프트 - member 10]
# 소비자 10의 한 달 소비 요약:
# - 총 지출: 4995211원, 총 탄소 배출: 31500.0kgCO₂
# - 탄소 감축 우선순위 Top 5 항목:
# • 오렌지주유소 (교통,수송): 탄소기여도 70.5%, 감축우선순위 점수 0.286, 추천 감축률 10% ~ 40% → 이유: 소비 변동성이 중간 수준이며, 10~40% 범위 감축이 가능합니다. (표준편차비: 0.69)
# • (주)에이비카페 (카페): 탄소기여도 2.3%, 감축우선순위 점수 0.211, 추천 감축률 10% ~ 40% → 이유: 소비 변동성이 중간 수준이며, 10~40% 범위 감축이 가능합니다. (표준편차비: 0.62)
# • 맥도날드 (음식점): 탄소기여도 0.6%, 감축우선순위 점수 0.204, 추천 감축률 0% ~ 10% → 이유: 해당 브랜드의 소비 기록이 적어, 안전하게 0~10% 감축만 권장됩니다.
# • 메가커피 (카페): 탄소기여도 0.4%, 감축우선순위 점수 0.204, 추천 감축률 10% ~ 40% → 이유: 소비 변동성이 중간 수준이며, 10~40% 범위 감축이 가능합니다. (표준편차비: 0.68)
# • 코스트코 (대형마트): 탄소기여도 11.9%, 감축우선순위 점수 0.049, 추천 감축률 10% ~ 40% → 이유: 소비 변동성이 중간 수준이며, 10~40% 범위 감축이 가능합니다. (표준편차비: 0.56)
#
# 이 소비자에게 탄소 감축을 위해 어떤 실천 전략이 가장 효과적일까요?
# 항목별로 감축률을 선택할 수 있게 유도하고, 총 감축 효과가 얼마나 될지도 예측해주세요.
# 다음과 같은 형식에 맞춰 구체적으로 답변해 주세요. 반드시 아래 구조를 따르되, 내용은 소비자 특성에 맞게 맞춤화해 주세요:
#
#
#     1. 소비자 인삿말 및 분석 요약
#
#     2. [현재 소비 패턴 분석]
#     - 총지출 대비 탄소 배출량 특이점
#     - 어떤 업종/브랜드가 주요 기여자인지
#     - 탄소 감축 가능성이 있는 소비 패턴
#     - 추천 감축률이 낮은 이유 (ex: 소비 기록 적음)
#
#     3. [감축 전략 제안]
#     - 외식/문화 등 업종별 구체적 조언 포함
#     - 실천 가능한 행동 위주로 제안
#
#     4. [Top 5 항목별 감축률 가이드]
#     아래 형식을 반복해서 제시:
#     - 브랜드명 (업종)
#     - 현재 탄소 기여도 (kgCO₂)
#     - 추천 감축률 (예: 0% / 5% / 10% / 20% / 30%)
#     - 실천 전략 (bullet 2~3개)
#     - 감축률별 감축 예상량 (계산 기반)
#
#     5. [총 감축 효과 예측]
#     - 예시 시나리오 제시
#     - 각 항목 감축률 선택 + 총 감축량 계산
#     - 감축 후 총 배출량 제시
#
#     6. [마무리 코멘트]
#     - 긍정적인 격려
#     - 다음 단계 제안
#
#     **반드시 위 양식을 지켜 작성해주세요.**
#
# [Gemini 응답 - member 10]
# 안녕하세요, 소비자 10님! 한 달간의 소비 데이터를 분석하여 탄소 감축을 위한 맞춤형 전략을 제안해 드립니다.
#
# ### 1. 소비자 인삿말 및 분석 요약
#
# 소비자 10님께서는 지난 한 달간 총 4,995,211원을 지출하셨고, 이로 인해 31,500.0kgCO₂의 탄소를 배출하셨습니다. 특히 교통/수송 분야의 '오렌지주유소'가 탄소 배출에 가장 큰 영향을 미치고 있으며, 대형마트인 '코스트코'도 상당한 비중을 차지하고 있습니다. 하지만 걱정하지 마세요! 몇 가지 실천 가능한 변화를 통해 탄소 배출량을 효과적으로 줄일 수 있습니다.
#
# ### 2. [현재 소비 패턴 분석]
#
# *   **총지출 대비 탄소 배출량 특이점**: 소비자 10님의 총 지출액 대비 탄소 배출량은 꽤 높은 편입니다. 특히 교통/수송 부문에서 발생하는 탄소 배출량이 전체의 70% 이상을 차지하고 있어, 이 부분이 탄소 감축의 핵심이 될 것으로 보입니다.
# *   **어떤 업종/브랜드가 주요 기여자인지**:
#     *   **교통/수송**: '오렌지주유소'가 압도적으로 높은 탄소 기여도(70.5%)를 보이며, 가장 중요한 감축 대상입니다.
#     *   **대형마트**: '코스트코'가 11.9%의 탄소 기여도로 두 번째로 높은 비중을 차지하고 있습니다.
#     *   **카페**: '(주)에이비카페'와 '메가커피'가 각각 2.3%, 0.4%로 비교적 낮은 기여도를 보이지만, 일상생활에서 쉽게 감축할 수 있는 항목입니다.
#     *   **음식점**: '맥도날드'는 0.6%로 기여도가 낮지만, 소비 기록이 적어 감축률을 보수적으로 제안합니다.
# *   **탄소 감축 가능성이 있는 소비 패턴**: '오렌지주유소', '(주)에이비카페', '메가커피', '코스트코'는 모두 소비 변동성이 중간 수준으로, 10%~40% 범위의 감축이 가능하다고 분석되었습니다. 이는 일상생활에서 조금만 신경 쓰면 충분히 탄소 배출량을 줄일 수 있다는 의미입니다.
# *   **추천 감축률이 낮은 이유 (ex: 소비 기록 적음)**: '맥도날드'의 경우, 해당 브랜드의 소비 기록이 적어 소비 패턴을 정확히 파악하기 어렵습니다. 따라서 안전하게 0%~10%의 보수적인 감축률을 권장합니다.
#
# ### 3. [감축 전략 제안]
#
# 소비자 10님의 탄소 감축을 위해 다음과 같은 실천 전략을 제안합니다.
#
# *   **교통/수송**: 가장 큰 비중을 차지하는 주유소 이용을 줄이는 것이 핵심입니다. 대중교통 이용, 카풀, 자전거 이용, 가까운 거리는 걷기 등 다양한 방법을 고려해 보세요.
# *   **대형마트**: 코스트코 방문 횟수를 줄이거나, 방문 시 필요한 물품만 구매하고 불필요한 소비를 줄이는 것이 중요합니다. 장바구니 사용은 기본입니다.
# *   **카페**: 개인 컵 사용을 생활화하고, 불필요한 일회용품 사용을 줄이는 것만으로도 탄소 배출량을 줄일 수 있습니다.
# *   **외식/문화**: 외식 시에는 로컬 푸드나 제철 식재료를 사용하는 식당을 선택하고, 음식물 쓰레기를 줄이는 노력을 해보세요.
#
# ### 4. [Top 5 항목별 감축률 가이드]
#
# 각 항목별로 목표 감축률을 선택하고, 그에 따른 예상 감축량을 확인해 보세요.
#
# *   **오렌지주유소 (교통,수송)**
#     *   현재 탄소 기여도: 22215.75 kgCO₂ (70.5%)
#     *   추천 감축률: 0% / 10% / 20% / 30% / 40%
#     *   실천 전략:
#         *   주 1회 대중교통 이용하기
#         *   가까운 거리는 자전거 이용 또는 걷기
#         *   카풀 참여 또는 전기차/하이브리드차 이용 고려
#     *   감축률별 감축 예상량:
#         *   0% 감축: 0 kgCO₂
#         *   10% 감축: 2221.58 kgCO₂
#         *   20% 감축: 4443.15 kgCO₂
#         *   30% 감축: 6664.73 kgCO₂
#         *   40% 감축: 8886.30 kgCO₂
#
# *   **(주)에이비카페 (카페)**
#     *   현재 탄소 기여도: 724.5 kgCO₂ (2.3%)
#     *   추천 감축률: 0% / 10% / 20% / 30% / 40%
#     *   실천 전략:
#         *   개인 컵 사용 생활화 (할인 혜택 활용)
#         *   테이크아웃 시 일회용품 사용 최소화
#         *   집에서 커피 내려 마시기
#     *   감축률별 감축 예상량:
#         *   0% 감축: 0 kgCO₂
#         *   10% 감축: 72.45 kgCO₂
#         *   20% 감축: 144.90 kgCO₂
#         *   30% 감축: 217.35 kgCO₂
#         *   40% 감축: 289.80 kgCO₂
#
# *   **맥도날드 (음식점)**
#     *   현재 탄소 기여도: 189.0 kgCO₂ (0.6%)
#     *   추천 감축률: 0% / 5% / 10%
#     *   실천 전략:
#         *   외식 시 음식물 남기지 않기
#         *   채식 메뉴 선택 고려
#         *   포장 시 다회용기 사용 문의
#     *   감축률별 감축 예상량:
#         *   0% 감축: 0 kgCO₂
#         *   5% 감축: 9.45 kgCO₂
#         *   10% 감축: 18.90 kgCO₂
#
# *   **메가커피 (카페)**
#     *   현재 탄소 기여도: 126.0 kgCO₂ (0.4%)
#     *   추천 감축률: 0% / 10% / 20% / 30% / 40%
#     *   실천 전략:
#         *   개인 컵 사용 생활화
#         *   불필요한 빨대 사용 자제
#         *   커피 대신 물 마시기
#     *   감축률별 감축 예상량:
#         *   0% 감축: 0 kgCO₂
#         *   10% 감축: 12.60 kgCO₂
#         *   20% 감축: 25.20 kgCO₂
#         *   30% 감축: 37.80 kgCO₂
#         *   40% 감축: 50.40 kgCO₂
#
# *   **코스트코 (대형마트)**
#     *   현재 탄소 기여도: 3748.5 kgCO₂ (11.9%)
#     *   추천 감축률: 0% / 10% / 20% / 30% / 40%
#     *   실천 전략:
#         *   방문 횟수 줄이기 (월 1회 등)
#         *   필요한 물품만 구매하고 충동구매 자제
#         *   장바구니 사용 생활화
#     *   감축률별 감축 예상량:
#         *   0% 감축: 0 kgCO₂
#         *   10% 감축: 374.85 kgCO₂
#         *   20% 감축: 749.70 kgCO₂
#         *   30% 감축: 1124.55 kgCO₂
#         *   40% 감축: 1499.40 kgCO₂
#
# ### 5. [총 감축 효과 예측]
#
# 소비자 10님께서 다음과 같이 감축률을 선택하신다면, 총 탄소 감축 효과는 다음과 같습니다.
#
# **예시 시나리오:**
#
# *   **오렌지주유소**: 20% 감축 선택 (4443.15 kgCO₂ 감축)
# *   **(주)에이비카페**: 30% 감축 선택 (217.35 kgCO₂ 감축)
# *   **맥도날드**: 5% 감축 선택 (9.45 kgCO₂ 감축)
# *   **메가커피**: 20% 감축 선택 (25.20 kgCO₂ 감축)
# *   **코스트코**: 10% 감축 선택 (374.85 kgCO₂ 감축)
#
# **총 감축량 계산:**
# 4443.15 + 217.35 + 9.45 + 25.20 + 374.85 = **5070.0 kgCO₂**
#
# **감축 후 총 배출량:**
# 31500.0 kgCO₂ (현재) - 5070.0 kgCO₂ (감축) = **26430.0 kgCO₂**
#
# 이 시나리오대로 실천하시면 한 달에 약 5톤의 탄소를 줄일 수 있으며, 이는 전체 탄소 배출량의 약 16%를 감축하는 효과를 가져옵니다!
#
# ### 6. [마무리 코멘트]
#
# 소비자 10님, 탄소 감축은 거창한 일이 아니라 일상 속 작은 실천에서 시작됩니다. 위에서 제안해 드린 전략들을 참고하여, 본인에게 가장 적합하고 실천 가능한 목표를 세워보세요. 작은 변화들이 모여 지구를 위한 큰 발걸음이 될 것입니다. 다음 달에는 더욱 줄어든 탄소 배출량을 확인할 수 있기를 기대합니다! 궁금한 점이 있다면 언제든지 다시 문의해주세요.
# --------------------------------------------------

# %% [markdown]
# # LLM 기반 ESG 금융 상품 추천

# %%
# -*- coding: utf-8 -*-
import os
import json
import requests
from PyPDF2 import PdfReader
from dotenv import load_dotenv

load_dotenv()
API_KEY  = os.getenv("GEMINI_API_KEY")
MODEL_ID = "gemini-2.5-flash"
ENDPOINT = (
    f"https://generativelanguage.googleapis.com/v1beta/models/"
    f"{MODEL_ID}:generateContent?key=AIzaSyAtHIIhgWL3Xam5OHWV0WblQUMW2VgnUdM"
)

# ▶ STEP 2: Gemini API 호출 함수
def call_gemini_api(prompt: str, temperature: float = 0.5, max_tokens: int = 4096) -> str:
    payload = {
        "contents": [{"parts": [{"text": prompt}]}],
        "generationConfig": {
            "temperature": temperature,
            "maxOutputTokens": max_tokens
        }
    }
    body = json.dumps(payload, ensure_ascii=False).encode("utf-8")
    headers = {"Content-Type": "application/json; charset=utf-8"}
    resp = requests.post(ENDPOINT, headers=headers, data=body)
    resp.raise_for_status()
    return resp.json()["candidates"][0]["content"]["parts"][0]["text"]

# ▶ STEP 3: PDF 텍스트 추출 함수
def extract_text_from_pdf(pdf_path):
    reader = PdfReader(pdf_path)
    return "\n".join([page.extract_text() for page in reader.pages if page.extract_text()])

# ▶ STEP 4: 프롬프트 생성 함수
def generate_prompt(pdf_text, filename):
    return f"""
다음은 금융상품 약관 문서 '{filename}'의 전문 내용입니다.

--------------------------
{pdf_text}
--------------------------

이 문서 내용을 기반으로 다음 정보를 작성해 주세요:

1. 이 문서의 핵심 요약 (5줄 이내)
2. 이 금융상품의 주요 특징 3가지
3. 이 문서와 관련된 추천 금융상품 3가지
   - 추천 이유 포함
   - 해당 금융상품이 적합한 고객 유형 포함
"""

# ▶ STEP 5: 전체 PDF 처리
def process_all_pdfs(folder_path):
    for filename in os.listdir(folder_path):
        if filename.endswith(".pdf"):
            pdf_path = os.path.join(folder_path, filename)
            print(f"\n📄 [처리 중] {filename}")
            pdf_text = extract_text_from_pdf(pdf_path)
            prompt = generate_prompt(pdf_text, filename)
            try:
                response = call_gemini_api(prompt)
                print(f"\n🧠 [Gemini 응답 - {filename}]\n{response}\n{'='*70}")
            except Exception as e:
                print(f"❌ Gemini API 호출 실패: {e}")

# ▶ STEP 6: 실행 경로 설정 후 실행
if __name__ == "__main__":
    pdf_path = "pdf/product1.pdf"
    pdf_text = extract_text_from_pdf(pdf_path)
    prompt = generate_prompt(pdf_text, os.path.basename(pdf_path))
    response = call_gemini_api(prompt)
    print(response)
# Out:
# 제공된 'product1.pdf' 문서를 기반으로 다음 정보를 작성했습니다.
#
# ---
#
# ### 1. 이 문서의 핵심 요약 (5줄 이내)
#
# KB Green Wave 1.5 ℃ 정기예금은 친환경 활동 실천 시 우대이율을 제공하는 1년제 정기예금입니다. 개인 및 개인사업자가 1백만원에서 1천만원까지 가입 가능하며, 최고 연 1.00%의 금리를 제공합니다. 종이통장 미발행, 친환경 상품 보유, 모바일 인증서 발급 등으로 우대이율을 받을 수 있습니다. 예금자보호 대상 상품이며 비과세종합저축 가입이 가능하나, 중도해지 시 약정이율보다 낮은 이율이 적용됩니다. 총 10만좌 한정 판매됩니다.
#
# ### 2. 이 금융상품의 주요 특징 3가지
#
# 1.  **친환경 활동 연계 우대이율 제공:** 종이통장 미발행(지구수호대), KB맑은하늘/바다적금 또는 KB국민 Green Wave 1.5 ℃ 카드 보유 및 결제실적(친환경패키지), KB모바일인증서 최초 발급 등 친환경 활동 실천 시 최고 연 0.45%p의 우대이율을 제공하여 최대 연 1.00%의 금리를 받을 수 있습니다.
# 2.  **명확한 가입 조건 및 판매 한정:** 개인 및 개인사업자를 대상으로 1인 1계좌, 1년제로 가입 가능하며, 가입금액은 1백만원 이상 1천만원 이하로 제한됩니다. 총 10만좌 한정 판매되어 한도 소진 시 조기 종료될 수 있습니다.
# 3.  **예금자 보호 및 세제 혜택:** 예금자보호법에 따라 원금과 이자를 합하여 1인당 최고 5천만원까지 보호되며, 비과세종합저축으로 가입하여 세제 혜택을 받을 수 있습니다. 단, 분할인출 및 재예치는 불가하며, 만기 전 해지 시 약정 이율보다 낮은 중도해지이율이 적용됩니다.
#
# ### 3. 이 문서와 관련된 추천 금융상품 3가지
#
# 1.  **KB맑은하늘적금 또는 KB맑은바다적금 (적금 상품)**
#     *   **추천 이유:** 'KB Green Wave 1.5 ℃ 정기예금'의 우대이율 조건 중 하나로 직접 언급된 상품입니다. 이 정기예금에 가입하면서 친환경 패키지 우대이율을 받고자 하는 고객에게 연계하여 추천할 수 있습니다.
#     *   **적합한 고객 유형:** 친환경 가치 소비를 지향하며, 정기적으로 소액을 저축하여 자산을 형성하고자 하는 고객.
#
# 2.  **일반 정기예금 (예: KB Star 정기예금 등)**
#     *   **추천 이유:** 'KB Green Wave 1.5 ℃ 정기예금'과 동일하게 안정적인 이자 수익을 목표로 하는 정기예금 상품입니다. 친환경 활동 조건 충족이 어렵거나, 1년 외의 다른 가입 기간을 선호하는 고객에게 대안으로 추천할 수 있습니다.
#     *   **적합한 고객 유형:** 안정적인 자산 운용을 선호하는 보수적 투자자, 친환경 활동 조건 충족 없이 고정금리 혜택을 받고자 하는 고객.
#
# 3.  **CMA (Cash Management Account) 또는 MMF (Money Market Fund)**
#     *   **추천 이유:** 'KB Green Wave 1.5 ℃ 정기예금'은 분할 인출이 불가하고 1년 만기 상품입니다. 단기 유동성 확보와 함께 수시 입출금이 가능하면서도 예금보다 높은 수익을 기대하는 고객에게 CMA나 MMF를 추천하여 자금의 효율성을 높일 수 있습니다.
#     *   **적합한 고객 유형:** 비상 자금 마련, 단기 여유 자금 운용, 수시 입출금이 잦아 유동성이 필요한 고객.

# %% [markdown]
# ## LLM 기반 저탄소 소비 특화 챗봇

# %%
import os
import json
import requests
from dotenv import load_dotenv

def load_api_key():
    load_dotenv()
    key = os.getenv("GEMINI_API_KEY")
    if not key:
        raise ValueError("GEMINI_API_KEY가 설정되지 않았습니다. .env 파일을 확인하세요.")
    return key

def generate_environmental_response(user_prompt: str) -> str:

    api_key = load_api_key()
    model_id = "gemini-2.5-flash"
    endpoint = f"https://generativelanguage.googleapis.com/v1beta/models/{model_id}:generateContent?key={api_key}"

    system_prompt = """당신은 저탄소 소비 특화 챗봇입니다. 사용자의 질문을 환경적 지속 가능성 관점에서 분석하고,
    실용적이고 구체적인 조언을 300자 이내로 제공해주세요.  """

    contents = [
        {
            "parts": [
                {"text": system_prompt},
                {"text": f"질문: {user_prompt}"}
            ]
        }
    ]

    payload = {
        "contents": contents,
        "generationConfig": {
            "temperature": 0.7,
            "candidateCount": 1,
            "maxOutputTokens": 2048,
            "topP": 0.8,
            "topK": 40
        },
        "safetySettings": [
            {
                "category": "HARM_CATEGORY_HARASSMENT",
                "threshold": "BLOCK_MEDIUM_AND_ABOVE"
            },
            {
                "category": "HARM_CATEGORY_HATE_SPEECH",
                "threshold": "BLOCK_MEDIUM_AND_ABOVE"
            }
        ]
    }

    headers = {"Content-Type": "application/json; charset=UTF-8"}

    try:
        response = requests.post(endpoint, headers=headers, json=payload, timeout=30)

        if response.status_code != 200:
            raise RuntimeError(f"API 실패: {response.status_code} - {response.text}")

        data = response.json()

        if "candidates" not in data or not data["candidates"]:
            raise ValueError("API 응답에 candidates가 없습니다.")

        candidate = data["candidates"][0]
        finish_reason = candidate.get("finishReason", "UNKNOWN")

        # 텍스트 추출
        result_text = ""

        # 1. 표준 구조: content.parts[].text
        if "content" in candidate and "parts" in candidate["content"]:
            parts = candidate["content"]["parts"]
            if isinstance(parts, list) and len(parts) > 0:
                for part in parts:
                    if isinstance(part, dict) and "text" in part:
                        result_text += part["text"]

        # 2. 직접 text 필드
        if not result_text and "text" in candidate:
            result_text = candidate["text"]

        # 3. content 직속 text 필드
        if not result_text and "content" in candidate and "text" in candidate["content"]:
            result_text = candidate["content"]["text"]

        # 4. 기타 가능한 필드들 확인
        if not result_text:
            possible_text_fields = ["output", "response", "answer", "message", "generated_text"]
            for field in possible_text_fields:
                if field in candidate:
                    result_text = str(candidate[field])
                    break

        return result_text.strip()

    except requests.exceptions.Timeout:
        return "API 요청 시간이 초과되었습니다. 다시 시도해주세요."
    except requests.exceptions.RequestException as e:
        return f"네트워크 오류가 발생했습니다: {str(e)}"
    except json.JSONDecodeError:
        return "API 응답을 파싱할 수 없습니다."
    except Exception as e:
        return f"처리 중 오류가 발생했습니다: {str(e)}"


def test_api_response_structure():
    try:
        test_prompt = "간단한 테스트 질문입니다."
        result = generate_environmental_response(test_prompt)
        return result
    except Exception as e:
        print(f"테스트 실패: {e}")
        return None


if __name__ == '__main__':
    test_result = test_api_response_structure()

    if test_result:
        # 사용자 프롬프트 입력
        user_prompt = "분리수거 하는 법 알려줘"
        answer = generate_environmental_response(user_prompt)
        print(answer)
# Out:
# 분리수거는 자원 순환의 핵심입니다. 환경적 지속 가능성을 위해 다음 원칙을 지켜주세요:
#
# 1.  **비우고 헹구기:** 내용물을 깨끗이 비우고 물로 헹궈 오염을 제거합니다. (음식물 오염 시 재활용 불가)
# 2.  **재질별 분리:** 플라스틱, 종이, 유리, 캔 등 재질별로 정확히 나눕니다.
# 3.  **라벨/뚜껑 분리:** 비닐 라벨, 금속 뚜껑 등 다른 재질은 제거 후 따로 배출합니다.
# 4.  **압축:** 부피를 줄여 효율적인 운반 및 재활용을 돕습니다.
#
# 이 작은 노력이 지구의 부담을 크게 줄입니다.
